# %% [markdown]
# <H1><center>
# Lab Assignment 4: <br>
#     Bayes Nets
# </center></H1>
#
# <center>
# <H2> Team Details: </H2>
# </center>
#
# |      Name        |  Roll Number  |
# |------------------|---------------|
# | Srajan Chourasia |    2003135    |
# | Shivam Sinoliya  |    2003132    |
#
# ## About:
# Developed code from scratch to compute an input probability query on a given Bayes net on discrete random variables using Prior sampling, Rejection Sampling, Likelihood weighting and Gibbs sampling. <br>
# We had also written helper function to generate samples from any input univariate discrete distribution and then use it in your Bayes Net sampling code.
#
# ## BayesNets Class:
# We implemented a BayesNets Class to do all the required task and computations.<br>
# Basically we created a single class to do all the calculation, extractions of details from the file as well as implement all the sampling methods and sample generation.

# %%
import random

class BayesNets():
    """
    A class to represent a Bayes Network.

    ...

    Attributes
    ----------
    filepath : str
        The File Path in string from which the data have to be extracted.

    Methods
    -------
    extractRV(verbose = True) -> None:
        This Function is used to extract the total number of random variables 
        and also there character representation from the file.
        
    extractConditionalProbability(verbose = True) -> None:
        This Function is used to extract all the conditional probability 
        tables from the file and stores these information in the dictionary 
        and all the tables in a single dictionary.    
        
    extractQuery(verbose = True) -> None:
        This Function is used to extract the query which is to be calculated 
        from the file.
    
    queryInfo(verbose = True) -> None:
        This Function is used to further extract information from the 
        extracted query. It is used to extract the information about the 
        dependent and conditional random variables from the query.

    generateSample(verbose = False) -> dict:
        This Function is used to generate a single sample randomly but 
        probability of each random variable selection is uniform.
    
    generateWeightedSample(verbose = True) -> tuple:
        This Function is used to generate a single sample randomly, but the 
        evidence will be fixed and each time any evidence is seen then 
        update the weights.

    doPriorSampling(TOTAL_SAMPLE = 10000, verbose = True) -> None:
        This Function is used to calculate the answer using the Prior Sampling.
        This function will simulate the Prior Sampling to calculate the answer 
        of the query.
        
    doRejectionSampling(TOTAL_SAMPLE_REQUIRED = 10000, verbose = True) -> None:
        This Function is used to calculate the answer using the Rejection 
        Sampling. This function will simulate the Rejection Sampling to 
        calculate the answer of the query.    
        
    doLikelihoodWeighting(TOTAL_SAMPLE = 10000, verbose = True) -> None:
        This Function is used to calculate the answer using the Likelihood 
        Weighting Sampling Method. This function will simulate the Likelihood 
        Weighting Sampling Method to calculate the answer of the query.
    
    doGibbsSampling(verbose = True) -> None:
        This Function is used to calculate the answer using the Gibbs Sampling.
        This function will simulate the Gibbs Sampling to calculate the answer 
        of the query.   
        
    """

    def __init__(self, filepath):
        """
        Constructor Function which initialize all the required variables as well 
        as start extracting all the information from the file passed as an argument
        using appropriate functions.

        Args:
            filepath: string
                The File Path in string from which the data have to be extracted.

        Returns:
            None

        Raises:
            FileNotFoundError: Raises an exception.
                File Does Not Exists or The Path is Wrong.
        """
        # Try Block to open the file.
        try:
            self.File = open(filepath, "r")
        except:
            # Raise the Error
            raise FileNotFoundError(
                "File Does Not Exists or The Path is Wrong.")
        else:
            # The Number of Random Variables.
            self.TotalRandomVariable = 0
            
            # The Information about the Random Variables
            self.RandomVariables = dict()
            
            # Extract the Information related to the Random Variables.
            self.extractRV()
            
            # Store the Conditional Probability in a Dictionary.
            self.ConditionalProbabilityTables = dict()
            
            # Store the Header Information in a Dictionary.
            self.ConditionalProbabilityHeader = dict()
            
            # Extract the Conditional Probability Tables from the file.
            self.extractConditionalProbability()
            
            # Store the Query.
            self.Query = ""
            self.ActualQuery = ""
            
            # Extract the Query from the file.
            self.extractQuery()
            
            # Since we had extracted all the information from the file, let's
            # close the file.
            self.File.close()
            
            # Store the Conditional Variables and the Dependent Variables.
            self.ConditionalVariables = dict()
            self.DependentVariables = dict()
            
            # Extract the Conditional Variables and the Dependent Variables.
            self.queryInfo()

    def __str__(self):
        """
        This method returns the string representation of the object. This method 
        is called when print() or str() function is invoked on an object. This 
        method must return the String object.
        """
        return (
            "-" * 60 + "\n" +
            f"Total Number of Random Variable: {self.TotalRandomVariable}\n" +
            "-" * 60 + "\n" +
            f"All Possible Random Variable Values: {self.RandomVariables}\n" +
            "-" * 60 + "\n" +
            f"Extracted Conditional Probability Header:\n{self.ConditionalProbabilityHeader}\n"
            + "-" * 60 + "\n" +
            f"Extracted Conditional Probability Tables:\n{self.ConditionalProbabilityTables}\n"
            + "-" * 60 + "\n" + f"Extracted Query: {self.Query}\n" + "-" * 60 +
            "\n" +
            f"Extracted Condition form the Query: {self.ActualQuery}\n" +
            "-" * 60 + "\n" +
            f"Final Extracted Conditional Values from the Query:\n {self.ConditionalVariables}\n"
            + "-" * 60 + "\n" +
            f"Final Extracted Depended Values from the Query:\n {self.DependentVariables}\n"
            + "-" * 60 + "\n")

    def extractRV(self, verbose=True) -> None:
        """
        This Function is used to extract the total number of random variables and also 
        there character representation from the file.

        Args:
            verbose: bool
                Print the log details to understand what exactly the function is
                doing as well as to understand the flow of the program.

        Returns:
            None

        Raises:
            ---
        """
        if verbose:
            print("Extracting The Random Variable Info...")
            
            # Read the line from the file.
            rv = self.File.readline().strip().split(',')
            print("Extracted The Random Variable Info from The File.")
            print(f"Info Extracted: {rv}")
            
            # convert it into a int.
            self.TotalRandomVariable = int(rv[0])
            print(
                f"Total Number of Random Variable: {self.TotalRandomVariable}")
            print("Start Extracting Random variables Possible Values...")
            
            # Extract all the possible option for the random variable.
            for i in range(self.TotalRandomVariable):
                self.RandomVariables[rv[i + 1].replace(" ", "")] = list()
            for j in range(self.TotalRandomVariable):
                extract = self.File.readline().strip().split(',')
                print(extract)
                for k in range(1, len(extract)):
                    self.RandomVariables[extract[0]].append(extract[k].replace(
                        " ", ""))
            print("Done Extracting Random variables Possible Values.")
            print(f"Possible Random Variable Values: {self.RandomVariables}\n")
        else:
            # Read the line from the file.
            rv = self.File.readline().strip().split(',')
            
            # convert it into a int.
            self.TotalRandomVariable = int(rv[0])
            
            # Extract all the possible option for the random variable.
            for i in range(self.TotalRandomVariable):
                self.RandomVariables[rv[i + 1].replace(" ", "")] = list()
            for j in range(self.TotalRandomVariable):
                extract = self.File.readline().strip().split(',')
                print(extract)
                for k in range(1, len(extract)):
                    self.RandomVariables[extract[0]].append(extract[k].replace(
                        " ", ""))

    def extractConditionalProbability(self, verbose=True) -> None:
        """
        This Function is used to extract all the conditional probability tables 
        from the file and stores these information in the dictionary and all the
        tables in a single dictionary.

        Args:
            verbose: bool
                Print the log details to understand what exactly the function is
                doing as well as to understand the flow of the program.

        Returns:
            None

        Raises:
            ---
        """
        if verbose:
            # get the Conditional Probability table.
            print("Start Extracting the Conditional Probability Table...")
            for i in range(self.TotalRandomVariable):
                about = self.File.readline().strip().split('|')
                print("-----------------------------")
                print(about)
                case = about[0].replace(' ', '')
                # variable = list()
                variable = about[-1].split(',')
                try:
                    variable = variable.remove('')
                    if variable == None:
                        variable = []
                except:
                    pass
                # Store the Conditional Probability in a Dictionary.
                self.ConditionalProbabilityTables[case] = dict()
                
                # Store the Header Information in a Dictionary.
                self.ConditionalProbabilityHeader[case] = list()
                print(variable)
                
                # store the header
                for head in variable:
                    self.ConditionalProbabilityHeader[case].append(
                        head.replace(' ', ''))
                
                # Iterate over the tables.
                for j in range(2**(len(variable) + 1)):
                    row = self.File.readline().strip().split(',')
                    print(row)
                    key = ""
                    for k in range(len(variable) + 1):
                        key += row[k].replace(' ', '')
                        key += " "
                    key = key[:-1]
                    probability = float(row[-1].replace(' ', ''))
                    # HashValueOfKey = hash(key)
                    self.ConditionalProbabilityTables[case][key] = probability
                print("-----------------------------")

            print(
                "Done Extracting the Conditional Probability Table from The File..."
            )
            print("***************************************")
            print(
                f"Extracted Conditional Probability Header: {self.ConditionalProbabilityHeader}"
            )
            print("***************************************")
            print(
                f"Extracted Conditional Probability Tables: {self.ConditionalProbabilityTables}"
            )
            print("***************************************\n")
        else:
            # get the Conditional Probability table.
            for i in range(self.TotalRandomVariable):
                about = self.File.readline().strip().split('|')
                case = about[0].replace(' ', '')
                # variable = list()
                variable = about[-1].split(',')
                try:
                    variable = variable.remove('')
                    if variable == None:
                        variable = []
                except:
                    pass
                # Store the Conditional Probability in a Dictionary.
                self.ConditionalProbabilityTables[case] = dict()
                
                # Store the Header Information in a Dictionary.
                self.ConditionalProbabilityHeader[case] = list()
                
                # store the header
                for head in variable:
                    self.ConditionalProbabilityHeader[case].append(
                        head.replace(' ', ''))

                # Iterate over the tables.
                for j in range(2**(len(variable) + 1)):
                    row = self.File.readline().strip().split(',')
                    key = ""
                    for k in range(len(variable) + 1):
                        key += row[k].replace(' ', '')
                        key += " "
                    key = key[:-1]
                    probability = float(row[-1].replace(' ', ''))
                    # HashValueOfKey = hash(key)
                    self.ConditionalProbabilityTables[case][key] = probability

    def extractQuery(self, verbose=True) -> None:
        """
        This Function is used to extract the query which is to be calculated from 
        the file.

        Args:
            verbose: bool
                Print the log details to understand what exactly the function is
                doing as well as to understand the flow of the program.

        Returns:
            None

        Raises:
            ---
        """
        if verbose:
            # Get the query from the file
            print("Start Extracting the Query from The File...")
            self.Query = self.File.readline().strip().split(": ")[-1]
            
            # print(type(Query))
            print("Done Extracting the Query from the File.")
            print(f"Extracted Query: {self.Query}")
            self.ActualQuery = self.Query[2:-1].replace(' ', '')
            print(f"Extracted Condition form the Query: {self.ActualQuery}\n")
        else:
            # Get the query from the file
            self.Query = self.File.readline().strip().split(": ")[-1]
            
            # print(type(Query))
            self.ActualQuery = self.Query[2:-1].replace(' ', '')

    def queryInfo(self, verbose=True) -> None:
        """
        This Function is used to further extract information from the extracted 
        query. It is used to extract the information about the dependent and 
        conditional random variables from the query.

        Args:
            verbose: bool
                Print the log details to understand what exactly the function is
                doing as well as to understand the flow of the program.

        Returns:
            None

        Raises:
            ---
        """
        if verbose:
            print("Start Extracting More Information From the Query...")
            
            # split the data into Conditional and Dependent Variables.
            variables = self.ActualQuery.split('|')
            if len(variables) == 2:
                conditionalVariables = variables[0]
                print(
                    "-------------------------------------------------------------------"
                )
                print(f"The Conditional Variables: {conditionalVariables}")
                dependentVariables = variables[1]
                print(f"The Dependent Variables: {dependentVariables}")
                print(
                    "-------------------------------------------------------------------"
                )
                
                # Now, extract them further.
                conditionalVariables = conditionalVariables.split(',')
                dependentVariables = dependentVariables.split(',')
                print(
                    "Extraction information for Conditional Variables From the Query..."
                )
                for i in conditionalVariables:
                    var, val = tuple(i.split('='))
                    var.replace(' ', '')
                    val.replace(' ', '')
                    self.ConditionalVariables[var] = val
                print(
                    f"Final Extracted Conditional Values from the Query:\n {self.ConditionalVariables}"
                )
                print(
                    "-------------------------------------------------------------------"
                )
                print(
                    f"Extraction information for Depended Variables From the Query..."
                )
                for j in dependentVariables:
                    var, val = tuple(j.split('='))
                    var.replace(' ', '')
                    val.replace(' ', '')
                    self.DependentVariables[var] = val
                print(
                    f"Final Extracted Depended Values from the Query:\n {self.DependentVariables}"
                )
                print(
                    "-------------------------------------------------------------------\n"
                )

            else:
                conditionalVariables = variables[0]
                print(f"The Conditional Variables: {conditionalVariables}")
                dependentVariables = None
                print(f"The Dependent Variables: {dependentVariables}")
                conditionalVariables = conditionalVariables.split(',')
                dependentVariables = dependentVariables.split(',')
                print(
                    "Extraction information for Conditional Variables From the Query..."
                )
                for i in conditionalVariables:
                    var, val = tuple(i.split('='))
                    var.replace(' ', '')
                    val.replace(' ', '')
                    self.ConditionalVariables[var] = val
                print(
                    f"Final Extracted Conditional Values from the Query:\n {self.ConditionalVariables}"
                )
                print(
                    "-------------------------------------------------------------------"
                )
                print(
                    f"Extraction information for Depended Variables From the Query..."
                )
                print(
                    f"Final Extracted Depended Values from the Query:\n {self.DependentVariables}"
                )
                print(
                    "-------------------------------------------------------------------\n"
                )

        else:
            # split the data into Conditional and Dependent Variables.
            variables = self.ActualQuery.split('|')
            if len(variables) == 2:
                conditionalVariables = variables[0]
                dependentVariables = variables[1]
                
                # Now, extract them further.
                conditionalVariables = conditionalVariables.split(',')
                dependentVariables = dependentVariables.split(',')
                for i in conditionalVariables:
                    var, val = tuple(i.split('='))
                    var.replace(' ', '')
                    val.replace(' ', '')
                    self.ConditionalVariables[var] = val
                for j in dependentVariables:
                    var, val = tuple(j.split('='))
                    var.replace(' ', '')
                    val.replace(' ', '')
                    self.DependentVariables[var] = val
            else:
                conditionalVariables = variables[0]
                dependentVariables = None
                conditionalVariables = conditionalVariables.split(',')
                dependentVariables = dependentVariables.split(',')
                for i in conditionalVariables:
                    var, val = tuple(i.split('='))
                    var.replace(' ', '')
                    val.replace(' ', '')
                    self.ConditionalVariables[var] = val

    def generateSample(self, verbose=False) -> dict:
        """
        This Function is used to generate a single sample randomly but probability 
        of each random variable selection is uniform.

        Args:
            verbose: bool
                Print the log details to understand what exactly the function is
                doing as well as to understand the flow of the program.

        Returns: dictionary
            The dictionary contain the random variables as key and the value as 
            the selected option of the random variable.
            example: {'B': '-b', 'E': '-e', 'A': '-a', 'J': '-j', 'M': '-m'}

        Raises:
            ---
        """
        # Store the sample in the dictionary.
        sample_visited = dict()
        if (not verbose):
            # iterate over all the random variables.
            for i in self.ConditionalProbabilityHeader:
                #     print(i)
                # Uniform Probability.
                probability = random.uniform(0, 1)
                #     print(probability)
                if len(self.ConditionalProbabilityHeader[i]) == 0:
                    # Choose the variable for a particular random variable using
                    # the uniform probability.
                    if self.ConditionalProbabilityTables[i][
                            self.RandomVariables[i][0]] > probability:
                        sample_visited[i] = self.RandomVariables[i][0]
                    else:
                        sample_visited[i] = self.RandomVariables[i][1]
                else:
                    # if the table is a conditional probability table, join the
                    # required sample calculated/chosen till now to select from
                    # the giver uniform probability.
                    sample = ""
                    for j in self.ConditionalProbabilityHeader[i]:
                        sample += sample_visited[j] + " "
                    possibility = []
                    for k in self.RandomVariables[i]:
                        possibility.append(sample + k)
                    if self.ConditionalProbabilityTables[i][
                            possibility[0]] > probability:
                        sample_visited[i] = self.RandomVariables[i][0]
                    else:
                        sample_visited[i] = self.RandomVariables[i][1]
        else:
            print("\nStarted Generating a Single Sample...")
            # iterate over all the random variables.
            for i in self.ConditionalProbabilityHeader:
                #     print(i)
                # Uniform Probability.
                probability = random.uniform(0, 1)
                #     print(probability)
                if len(self.ConditionalProbabilityHeader[i]) == 0:
                    # Choose the variable for a particular random variable using
                    # the uniform probability.
                    if self.ConditionalProbabilityTables[i][
                            self.RandomVariables[i][0]] > probability:
                        sample_visited[i] = self.RandomVariables[i][0]
                    else:
                        sample_visited[i] = self.RandomVariables[i][1]
                else:
                    # if the table is a conditional probability table, join the
                    # required sample calculated/chosen till now to select from
                    # the giver uniform probability.
                    sample = ""
                    for j in self.ConditionalProbabilityHeader[i]:
                        sample += sample_visited[j] + " "
                    possibility = []
                    for k in self.RandomVariables[i]:
                        possibility.append(sample + k)
                    if self.ConditionalProbabilityTables[i][
                            possibility[0]] > probability:
                        sample_visited[i] = self.RandomVariables[i][0]
                    else:
                        sample_visited[i] = self.RandomVariables[i][1]
            
                # Print the sample constructed till now.
                print(
                    "---------------------------------------------------------------------------------"
                )
                print(
                    f"With Probability {probability}: {sample_visited} is chosen till now..."
                )
            
            # print the final sample generated.
            print(
                "*********************************************************************************"
            )
            print(f"Final Sample Generated: {sample_visited}")
            print(
                "*********************************************************************************\n"
            )
        
        # return the sample.
        return sample_visited

    def doPriorSampling(self, TOTAL_SAMPLE=10000, verbose=True) -> None:
        """
        This Function is used to calculate the answer using the Prior Sampling.
        This function will simulate the Prior Sampling to calculate the answer 
        of the query.

        Args:
            verbose: bool
                Print the log details to understand what exactly the function is
                doing as well as to understand the flow of the program.
            
            TOTAL_SAMPLE: Int
                Default: 10000
                Run the simulation for total TOTAL_SAMPLE iterations, and generate 
                a total of TOTAL_SAMPLE samples.

        Returns:
            None
                
        Raises:
            ---
        """
        # total number of sample with all the requirement fulfilled.
        requiredSample = 0
        
        # total number of sample where the evidence is seen.
        evidence = 0
        if (verbose):
            print(
                "------------ CALCULATE THE QUERY USING PRIOR SAMPLING ------------"
            )
            print("Started Generating The Sample...")
            
            # Iterate for TOTAL_SAMPLE of times.
            for iteration in range(1, TOTAL_SAMPLE + 1):
                # generate a single sample.
                sample = self.generateSample()
                if len(self.DependentVariables) > 0:
                    flag = True
                    
                    # check for the evidence.
                    for key, value in self.DependentVariables.items():
                        if value != sample[key]:
                            flag = False
                            break
                    if flag:
                        evidence += 1
                        flag = True
                        
                        # check for the required sample.
                        for key, value in self.ConditionalVariables.items():
                            if value != sample[key]:
                                flag = False
                                break
                        if flag:
                            requiredSample += 1

                    # After every 100 iteration print the current status.
                    if iteration % 100 == 0:
                        print("************************************")
                        print(f"STATUS: Iteration Number -->{iteration}<--")
                        print(f"Evidence Seen: {evidence}")
                        print(f"Required Sample Seen: {requiredSample}")
                        print("************************************")

                else:
                    flag = True
                    
                    # check for the required sample.
                    for key, value in self.ConditionalVariables.items():
                        if value != sample[key]:
                            flag = False
                            break
                    if flag:
                        requiredSample += 1

                    # After every 100 iteration print the current status.
                    if iteration % 100 == 0:
                        print("************************************")
                        print(f"STATUS: Iteration Number -->{iteration}<--")
                        print(f"Required Sample Seen: {requiredSample}")
                        print("************************************")

        else:
            print(
                "------------ CALCULATE THE QUERY USING PRIOR SAMPLING ------------"
            )
            
            # Iterate for TOTAL_SAMPLE of times.
            for iteration in range(1, TOTAL_SAMPLE + 1):
                # generate a single sample.
                sample = self.generateSample()
                if len(self.DependentVariables) > 0:
                    flag = True
                    
                    # check for the evidence.
                    for key, value in self.DependentVariables.items():
                        if value != sample[key]:
                            flag = False
                            break
                    if flag:
                        evidence += 1
                        flag = True
                       
                        # check for the required sample.
                        for key, value in self.ConditionalVariables.items():
                            if value != sample[key]:
                                flag = False
                                break
                        if flag:
                            requiredSample += 1

                else:
                    flag = True
                    
                    # check for the required sample.
                    for key, value in self.ConditionalVariables.items():
                        if value != sample[key]:
                            flag = False
                            break
                    if flag:
                        requiredSample += 1

        # Print the final Result.
        print(
            "------------------------------------------------------------------"
        )
        print(f"Completed {TOTAL_SAMPLE} Iterators of Sampling.")
        print("Final Result:")
        print(f"Total Sample Generated = {TOTAL_SAMPLE}")
        print(
            f"Total Required Sample Seen: {self.ConditionalVariables} | {self.DependentVariables} = {requiredSample}"
        )
        if len(self.DependentVariables) > 0:
            print(
                f"Total Evidence Seen: {self.DependentVariables} = {evidence}")
            print(f"Probability = {requiredSample/evidence}")
        else:
            print(f"Probability = {requiredSample/TOTAL_SAMPLE}")
        print(
            "------------------------------------------------------------------\n"
        )

    def doRejectionSampling(self,
                            TOTAL_SAMPLE_REQUIRED=10000,
                            verbose=True) -> None:
        """
        This Function is used to calculate the answer using the Rejection Sampling.
        This function will simulate the Rejection Sampling to calculate the answer 
        of the query.

        Args:
            verbose: bool
                Print the log details to understand what exactly the function is
                doing as well as to understand the flow of the program.
            
            TOTAL_SAMPLE_REQUIRED: Int
                Default: 10000
                Run the simulation till the program had seen a total of 
                TOTAL_SAMPLE_REQUIRED evidences, and the function will keep on
                generation samples until the total number of evidence are seen.

        Returns:
            None
                
        Raises:
            ---
        """
        # number of total sample generated.
        total_sample_generated = 0
        
        # number of total required sample seen.
        total_seen_sample = 0
        
        # number of times evidence is seen.
        evidence = 0
        if (verbose):
            print(
                "------------ CALCULATE THE QUERY USING REJECTION SAMPLING ------------"
            )
            print("Started Generating The Sample...")
            
            # keep on generating sample until meet a particulate condition.
            while (True):
                # Count the total number of sample generated.
                total_sample_generated += 1
                
                # generate a single sample.
                sample = self.generateSample()
                if len(self.DependentVariables) > 0:
                    flag = True
                    
                    # check for the evidence.
                    for key, value in self.DependentVariables.items():
                        if value != sample[key]:
                            flag = False
                            break
                    if flag:
                        evidence += 1
                        flag = True
                        
                        # check for the required sample.
                        for key, value in self.ConditionalVariables.items():
                            if value != sample[key]:
                                flag = False
                                break
                        
                        # increase the count of total_seen_sample by 1.
                        if flag:
                            total_seen_sample += 1

                    # After every 1000 iteration print the current status.
                    if total_sample_generated % 1000 == 0:
                        print("************************************")
                        print(
                            f"STATUS: Iteration Number -->{total_sample_generated}<--"
                        )
                        print(
                            f"Total Sample Generated: {total_sample_generated}"
                        )
                        print(
                            f"Total Sample Rejected: {total_sample_generated - evidence}"
                        )
                        print(f"Total Sample Accepted: {evidence}")
                        print(f"Evidence Seen: {evidence}")
                        print(f"Required Sample Seen: {total_seen_sample}")
                        print("************************************")

                else:
                    flag = True
                    
                    # check for the required sample.
                    for key, value in self.ConditionalVariables.items():
                        if value != sample[key]:
                            flag = False
                            break
                    
                    # increase the count of total_seen_sample and evidence by 1.
                    if flag:
                        total_seen_sample += 1
                        evidence += 1

                    # After every 1000 iteration print the current status.
                    if total_sample_generated % 1000 == 0:
                        print("************************************")
                        print(
                            f"STATUS: Iteration Number -->{total_sample_generated}<--"
                        )
                        print(
                            f"Total Sample Generated: {total_sample_generated}"
                        )
                        print(
                            f"Total Sample Rejected: {total_sample_generated - total_seen_sample}"
                        )
                        print(f"Total Sample Accepted: {evidence}")
                        print(f"Required Sample Seen: {total_seen_sample}")
                        print("************************************")

                # if we have seen the required amount of evidence, then break.
                if evidence == TOTAL_SAMPLE_REQUIRED:
                    break

        else:
            print(
                "------------ CALCULATE THE QUERY USING REJECTION SAMPLING ------------"
            )
            while (True):
                # Count the total number of sample generated.
                total_sample_generated += 1
                
                # generate a single sample.
                sample = self.generateSample()
                if len(self.DependentVariables) > 0:
                    flag = True
                    
                    # check for the evidence.
                    for key, value in self.DependentVariables.items():
                        if value != sample[key]:
                            flag = False
                            break
                    if flag:
                        evidence += 1
                        flag = True
                        
                        # check for the required sample.
                        for key, value in self.ConditionalVariables.items():
                            if value != sample[key]:
                                flag = False
                                break
                        if flag:
                            total_seen_sample += 1

                else:
                    flag = True
                    
                    # check for the required sample.
                    for key, value in self.ConditionalVariables.items():
                        if value != sample[key]:
                            flag = False
                            break

                    # increase the count of total_seen_sample and evidence by 1.
                    if flag:
                        total_seen_sample += 1
                        evidence += 1

                # if we have seen the required amount of evidence, then break.
                if evidence == TOTAL_SAMPLE_REQUIRED:
                    break

        # Print the final result.
        print("-----------------------------------------------------------")
        print(f"Completed {total_sample_generated} Iterators of Sampling.")
        print("Final Result:")
        print(f"Total Sample Generated = {total_sample_generated}")
        print(
            f"Total Sample Rejected = {total_sample_generated - total_seen_sample}"
        )
        print(f"Total Sample Accepted = {evidence}")
        # print(f"Total Evidence Seen = {evidence}")
        print(
            f"Total Required Sample Seen: {self.ConditionalVariables} | {self.DependentVariables} = {total_seen_sample}"
        )
        if len(self.DependentVariables) > 0:
            print(
                f"Total Evidence Seen: {self.DependentVariables} = {evidence}")
            print(f"Probability = {total_seen_sample/TOTAL_SAMPLE_REQUIRED}")
        else:
            print(f"Probability = {total_seen_sample/total_sample_generated}")
        print("-----------------------------------------------------------\n")

    def generateWeightedSample(self, verbose=True) -> tuple:
        """
        This Function is used to generate a single sample randomly, but the evidence
        will be fixed and each time any evidence is seen then update the weights.

        Args:
            verbose: bool
                Print the log details to understand what exactly the function is
                doing as well as to understand the flow of the program.

        Returns: tuple
            The tuple contain a dictionary which contains the random variables as 
            key and the value as the selected option of the random variable, as 
            well the final weight. 
            example: ({'B': '-b', 'E': '-e', 'A': '-a', 'J': '+j', 'M': '-m'}, 0.05)

        Raises:
            ---
        """
        # Store the sample in the dictionary.
        sample_visited = dict()
        
        # Store the weights.
        sample_weight = 1
        if (not verbose):
            for i in self.ConditionalProbabilityHeader:
                #     print(i)
                if i not in self.DependentVariables:
                    probability = random.uniform(0, 1)
                    #     print(probability)
                    if len(self.ConditionalProbabilityHeader[i]) == 0:
                        if self.ConditionalProbabilityTables[i][
                                self.RandomVariables[i][0]] > probability:
                            sample_visited[i] = self.RandomVariables[i][0]
                        else:
                            sample_visited[i] = self.RandomVariables[i][1]
                    else:
                        sample = ""
                        for j in self.ConditionalProbabilityHeader[i]:
                            sample += sample_visited[j] + " "
                        possibility = []
                        for k in self.RandomVariables[i]:
                            possibility.append(sample + k)
                        if self.ConditionalProbabilityTables[i][
                                possibility[0]] > probability:
                            sample_visited[i] = self.RandomVariables[i][0]
                        else:
                            sample_visited[i] = self.RandomVariables[i][1]
                else:
                    # Fix the Evidence.
                    if len(self.ConditionalProbabilityHeader[i]) >= 0:
                        sample_visited[i] = self.DependentVariables[i]
                        sample = ""
                        for j in self.ConditionalProbabilityHeader[i]:
                            sample += sample_visited[j] + " "
                        sample += self.DependentVariables[i]
                        sample_weight *= self.ConditionalProbabilityTables[i][
                            sample]
                    sample_visited[i] = self.DependentVariables[i]

        else:
            print("\nStarted Generating a Single Sample...")
            for i in self.ConditionalProbabilityHeader:
                #     print(i)
                if i not in self.DependentVariables:
                    probability = random.uniform(0, 1)
                    #     print(probability)
                    if len(self.ConditionalProbabilityHeader[i]) == 0:
                        if self.ConditionalProbabilityTables[i][
                                self.RandomVariables[i][0]] > probability:
                            sample_visited[i] = self.RandomVariables[i][0]
                        else:
                            sample_visited[i] = self.RandomVariables[i][1]
                    else:
                        sample = ""
                        for j in self.ConditionalProbabilityHeader[i]:
                            sample += sample_visited[j] + " "
                        possibility = []
                        for k in self.RandomVariables[i]:
                            possibility.append(sample + k)
                        if self.ConditionalProbabilityTables[i][
                                possibility[0]] > probability:
                            sample_visited[i] = self.RandomVariables[i][0]
                        else:
                            sample_visited[i] = self.RandomVariables[i][1]
                    print(
                        "---------------------------------------------------------------------------------"
                    )
                    print(
                        f"With Probability {probability}: {sample_visited} is chosen till now..."
                    )
                else:
                    # Fix the Evidence.
                    print(
                        "---------------------------------------------------------------------------------"
                    )
                    print(
                        f"Fixing The Sample: {i} = {self.DependentVariables[i]}"
                    )
                    if len(self.ConditionalProbabilityHeader[i]) >= 0:
                        sample = ""
                        for j in self.ConditionalProbabilityHeader[i]:
                            sample += sample_visited[j] + " "
                        sample += self.DependentVariables[i]
                        sample_weight *= self.ConditionalProbabilityTables[i][
                            sample]
                    sample_visited[i] = self.DependentVariables[i]
                    print(f"Sample Chosen Till Now: {sample_visited}")
                    print(f"Updated Sample Weights are: {sample_weight}")
            print(
                "*********************************************************************************"
            )
            print(f"Final Sample Generated: {sample_visited}")
            print(f"Final Weight: {sample_weight}")
            print(
                "*********************************************************************************\n"
            )
        
        # return the sample generated and the final weight.
        return (sample_visited, sample_weight)

    def doLikelihoodWeighting(self, TOTAL_SAMPLE=10000, verbose=True) -> None:
        """
        This Function is used to calculate the answer using the Likelihood Weighting
        Sampling Method. This function will simulate the Likelihood Weighting
        Sampling Method to calculate the answer of the query.

        Args:
            verbose: bool
                Print the log details to understand what exactly the function is
                doing as well as to understand the flow of the program.
            
            TOTAL_SAMPLE: Int
                Default: 10000
                Run the simulation for total TOTAL_SAMPLE iterations, and generate 
                a total of TOTAL_SAMPLE weighted samples.

        Returns:
            None
                
        Raises:
            ---
        """
        # total required sample weight.
        requiredSampleWeight = 0.0
        
        # total evidence weight.
        evidenceWeight = 0.0
        if (verbose):
            print(
                "------------ CALCULATE THE QUERY USING LIKELIHOOD WEIGHTING ------------"
            )
            print("Started Generating The Sample...")
            
            # iterate for exact TOTAL_SAMPLE number of times.
            for iteration in range(1, TOTAL_SAMPLE + 1):
                # generate a single weighted sample.
                sample, weight = self.generateWeightedSample(verbose=False)
                evidenceWeight += weight
                flag = True
                
                # check for the required sample.
                for key, value in self.ConditionalVariables.items():
                    if value != sample[key]:
                        flag = False
                        break
                if flag:
                    # increment the requiredSampleWeight by the weight.
                    requiredSampleWeight += weight

                # After every 100 iteration print the current status.
                if iteration % 100 == 0:
                    print("************************************")
                    print(f"STATUS: Iteration Number -->{iteration}<--")
                    print(f"Total Evidence Weight: {evidenceWeight}")
                    print(
                        f"Total Required Sample Weight: {requiredSampleWeight}"
                    )
                    print("************************************")

        else:
            print(
                "------------ CALCULATE THE QUERY USING LIKELIHOOD WEIGHTING ------------"
            )
            # iterate for exact TOTAL_SAMPLE number of times.
            for iteration in range(1, TOTAL_SAMPLE + 1):
                # generate a single weighted sample.
                sample, weight = self.generateWeightedSample(verbose=False)
                evidenceWeight += weight
                flag = True
                
                # check for the required sample.
                for key, value in self.ConditionalVariables.items():
                    if value != sample[key]:
                        flag = False
                        break
                if flag:
                    # increment the requiredSampleWeight by the weight.
                    requiredSampleWeight += weight

        # Print the final OUTPUT.
        print(
            "------------------------------------------------------------------"
        )
        print(f"Completed {TOTAL_SAMPLE} Iterators of Sampling.")
        print("Final Result:")
        print(f"Total Sample Generated = {TOTAL_SAMPLE}")
        print(
            f"Total Required Sample Weight Seen: {self.ConditionalVariables} | {self.DependentVariables} = {requiredSampleWeight}"
        )
        print(
            f"Total Evidence Weight Seen: {self.DependentVariables} = {evidenceWeight}"
        )
        print(f"Probability = {requiredSampleWeight/evidenceWeight}")
        print(
            "------------------------------------------------------------------\n"
        )

    def doGibbsSampling(self, verbose=True):
        """
        This Function is used to calculate the answer using the Gibbs Sampling.
        This function will simulate the Gibbs Sampling to calculate the answer 
        of the query.
        """
        print("Not Yet Implemented!")
        pass

# %% [markdown]
# ## To Get more information about the BayesNets Class as well as its methods:
# ### run the following command:
# ```
# help(BayesNets)
# ```

# %%
help(BayesNets)
# Out:
# Help on class BayesNets in module __main__:
#
# class BayesNets(builtins.object)
#  |  BayesNets(filepath)
#  |
#  |  A class to represent a Bayes Network.
#  |
#  |  ...
#  |
#  |  Attributes
#  |  ----------
#  |  filepath : str
#  |      The File Path in string from which the data have to be extracted.
#  |
#  |  Methods
#  |  -------
#  |  extractRV(verbose = True) -> None:
#  |      This Function is used to extract the total number of random variables
#  |      and also there character representation from the file.
#  |
#  |  extractConditionalProbability(verbose = True) -> None:
#  |      This Function is used to extract all the conditional probability
#  |      tables from the file and stores these information in the dictionary
#  |      and all the tables in a single dictionary.
#  |
#  |  extractQuery(verbose = True) -> None:
#  |      This Function is used to extract the query which is to be calculated
#  |      from the file.
#  |
#  |  queryInfo(verbose = True) -> None:
#  |      This Function is used to further extract information from the
#  |      extracted query. It is used to extract the information about the
#  |      dependent and conditional random variables from the query.
#  |
#  |  generateSample(verbose = False) -> dict:
#  |      This Function is used to generate a single sample randomly but
#  |      probability of each random variable selection is uniform.
#  |
#  |  generateWeightedSample(verbose = True) -> tuple:
#  |      This Function is used to generate a single sample randomly, but the
#  |      evidence will be fixed and each time any evidence is seen then
#  |      update the weights.
#  |
#  |  doPriorSampling(TOTAL_SAMPLE = 10000, verbose = True) -> None:
#  |      This Function is used to calculate the answer using the Prior Sampling.
#  |      This function will simulate the Prior Sampling to calculate the answer
#  |      of the query.
#  |
#  |  doRejectionSampling(TOTAL_SAMPLE_REQUIRED = 10000, verbose = True) -> None:
#  |      This Function is used to calculate the answer using the Rejection
#  |      Sampling. This function will simulate the Rejection Sampling to
#  |      calculate the answer of the query.
#  |
#  |  doLikelihoodWeighting(TOTAL_SAMPLE = 10000, verbose = True) -> None:
#  |      This Function is used to calculate the answer using the Likelihood
#  |      Weighting Sampling Method. This function will simulate the Likelihood
#  |      Weighting Sampling Method to calculate the answer of the query.
#  |
#  |  doGibbsSampling(verbose = True) -> None:
#  |      This Function is used to calculate the answer using the Gibbs Sampling.
#  |      This function will simulate the Gibbs Sampling to calculate the answer
#  |      of the query.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, filepath)
#  |      Constructor Function which initialize all the required variables as well
#  |      as start extracting all the information from the file passed as an argument
#  |      using appropriate functions.
#  |
#  |      Args:
#  |          filepath: string
#  |              The File Path in string from which the data have to be extracted.
#  |
#  |      Returns:
#  |          None
#  |
#  |      Raises:
#  |          FileNotFoundError: Raises an exception.
#  |              File Does Not Exists or The Path is Wrong.
#  |
#  |  __str__(self)
#  |      This method returns the string representation of the object. This method
#  |      is called when print() or str() function is invoked on an object. This
#  |      method must return the String object.
#  |
#  |  doGibbsSampling(self, verbose=True)
#  |      This Function is used to calculate the answer using the Gibbs Sampling.
#  |      This function will simulate the Gibbs Sampling to calculate the answer
#  |      of the query.
#  |
#  |  doLikelihoodWeighting(self, TOTAL_SAMPLE=10000, verbose=True) -> None
#  |      This Function is used to calculate the answer using the Likelihood Weighting
#  |      Sampling Method. This function will simulate the Likelihood Weighting
#  |      Sampling Method to calculate the answer of the query.
#  |
#  |      Args:
#  |          verbose: bool
#  |              Print the log details to understand what exactly the function is
#  |              doing as well as to understand the flow of the program.
#  |
#  |          TOTAL_SAMPLE: Int
#  |              Default: 10000
#  |              Run the simulation for total TOTAL_SAMPLE iterations, and generate
#  |              a total of TOTAL_SAMPLE weighted samples.
#  |
#  |      Returns:
#  |          None
#  |
#  |      Raises:
#  |          ---
#  |
#  |  doPriorSampling(self, TOTAL_SAMPLE=10000, verbose=True) -> None
#  |      This Function is used to calculate the answer using the Prior Sampling.
#  |      This function will simulate the Prior Sampling to calculate the answer
#  |      of the query.
#  |
#  |      Args:
#  |          verbose: bool
#  |              Print the log details to understand what exactly the function is
#  |              doing as well as to understand the flow of the program.
#  |
#  |          TOTAL_SAMPLE: Int
#  |              Default: 10000
#  |              Run the simulation for total TOTAL_SAMPLE iterations, and generate
#  |              a total of TOTAL_SAMPLE samples.
#  |
#  |      Returns:
#  |          None
#  |
#  |      Raises:
#  |          ---
#  |
#  |  doRejectionSampling(self, TOTAL_SAMPLE_REQUIRED=10000, verbose=True) -> None
#  |      This Function is used to calculate the answer using the Rejection Sampling.
#  |      This function will simulate the Rejection Sampling to calculate the answer
#  |      of the query.
#  |
#  |      Args:
#  |          verbose: bool
#  |              Print the log details to understand what exactly the function is
#  |              doing as well as to understand the flow of the program.
#  |
#  |          TOTAL_SAMPLE_REQUIRED: Int
#  |              Default: 10000
#  |              Run the simulation till the program had seen a total of
#  |              TOTAL_SAMPLE_REQUIRED evidences, and the function will keep on
#  |              generation samples until the total number of evidence are seen.
#  |
#  |      Returns:
#  |          None
#  |
#  |      Raises:
#  |          ---
#  |
#  |  extractConditionalProbability(self, verbose=True) -> None
#  |      This Function is used to extract all the conditional probability tables
#  |      from the file and stores these information in the dictionary and all the
#  |      tables in a single dictionary.
#  |
#  |      Args:
#  |          verbose: bool
#  |              Print the log details to understand what exactly the function is
#  |              doing as well as to understand the flow of the program.
#  |
#  |      Returns:
#  |          None
#  |
#  |      Raises:
#  |          ---
#  |
#  |  extractQuery(self, verbose=True) -> None
#  |      This Function is used to extract the query which is to be calculated from
#  |      the file.
#  |
#  |      Args:
#  |          verbose: bool
#  |              Print the log details to understand what exactly the function is
#  |              doing as well as to understand the flow of the program.
#  |
#  |      Returns:
#  |          None
#  |
#  |      Raises:
#  |          ---
#  |
#  |  extractRV(self, verbose=True) -> None
#  |      This Function is used to extract the total number of random variables and also
#  |      there character representation from the file.
#  |
#  |      Args:
#  |          verbose: bool
#  |              Print the log details to understand what exactly the function is
#  |              doing as well as to understand the flow of the program.
#  |
#  |      Returns:
#  |          None
#  |
#  |      Raises:
#  |          ---
#  |
#  |  generateSample(self, verbose=False) -> dict
#  |      This Function is used to generate a single sample randomly but probability
#  |      of each random variable selection is uniform.
#  |
#  |      Args:
#  |          verbose: bool
#  |              Print the log details to understand what exactly the function is
#  |              doing as well as to understand the flow of the program.
#  |
#  |      Returns: dictionary
#  |          The dictionary contain the random variables as key and the value as
#  |          the selected option of the random variable.
#  |          example: {'B': '-b', 'E': '-e', 'A': '-a', 'J': '-j', 'M': '-m'}
#  |
#  |      Raises:
#  |          ---
#  |
#  |  generateWeightedSample(self, verbose=True) -> tuple
#  |      This Function is used to generate a single sample randomly, but the evidence
#  |      will be fixed and each time any evidence is seen then update the weights.
#  |
#  |      Args:
#  |          verbose: bool
#  |              Print the log details to understand what exactly the function is
#  |              doing as well as to understand the flow of the program.
#  |
#  |      Returns: tuple
#  |          The tuple contain a dictionary which contains the random variables as
#  |          key and the value as the selected option of the random variable, as
#  |          well the final weight.
#  |          example: ({'B': '-b', 'E': '-e', 'A': '-a', 'J': '+j', 'M': '-m'}, 0.05)
#  |
#  |      Raises:
#  |          ---
#  |
#  |  queryInfo(self, verbose=True) -> None
#  |      This Function is used to further extract information from the extracted
#  |      query. It is used to extract the information about the dependent and
#  |      conditional random variables from the query.
#  |
#  |      Args:
#  |          verbose: bool
#  |              Print the log details to understand what exactly the function is
#  |              doing as well as to understand the flow of the program.
#  |
#  |      Returns:
#  |          None
#  |
#  |      Raises:
#  |          ---
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# ## Lets Start By Creating an object of BayesNets and extract the information from the file:

# %%
bayesNet = BayesNets(filepath = "example_bayesnet.txt")
# Out:
# Extracting The Random Variable Info...
# Extracted The Random Variable Info from The File.
# Info Extracted: ['5', ' B', ' E', ' A', ' J', ' M']
# Total Number of Random Variable: 5
# Start Extracting Random variables Possible Values...
# ['B', ' +b', ' -b']
# ['E', ' +e', ' -e']
# ['A', ' +a', ' -a']
# ['J', ' +j', ' -j']
# ['M', ' +m', ' -m']
# Done Extracting Random variables Possible Values.
# Possible Random Variable Values: {'B': ['+b', '-b'], 'E': ['+e', '-e'], 'A': ['+a', '-a'], 'J': ['+j', '-j'], 'M': ['+m', '-m']}
#
# Start Extracting the Conditional Probability Table...
# -----------------------------
# ['B ', '']
# []
# ['+b', ' 0.001']
# ['-b', ' 0.999']
# -----------------------------
# -----------------------------
# ['E ', '']
# []
# ['+e', ' 0.002']
# ['-e', ' 0.998']
# -----------------------------
# -----------------------------
# ['A ', ' B,E']
# [' B', 'E']
# ['+b', ' +e', ' +a', ' 0.95']
# ['+b', ' +e', ' -a', ' 0.05']
# ['+b', ' -e', ' +a', ' 0.94']
# ['+b', ' -e', ' -a', ' 0.06']
# ['-b', ' +e', ' +a', ' 0.29']
# ['-b', ' +e', ' -a', ' 0.71']
# ['-b', ' -e', ' +a', ' 0.001']
# ['-b', ' -e', ' -a', ' 0.999']
# -----------------------------
# -----------------------------
# ['J ', ' A']
# [' A']
# ['+a', ' +j', ' 0.9']
# ['+a', ' -j', ' 0.1']
# ['-a', ' +j', ' 0.05']
# ['-a', ' -j', ' 0.95']
# -----------------------------
# -----------------------------
# ['M ', ' A']
# [' A']
# ['+a', ' +m', ' 0.7']
# ['+a', ' -m', ' 0.3']
# ['-a', ' +m', ' 0.01']
# ['-a', ' -m', ' 0.99']
# -----------------------------
# Done Extracting the Conditional Probability Table from The File...
# ***************************************
# Extracted Conditional Probability Header: {'B': [], 'E': [], 'A': ['B', 'E'], 'J': ['A'], 'M': ['A']}
# ***************************************
# Extracted Conditional Probability Tables: {'B': {'+b': 0.001, '-b': 0.999}, 'E': {'+e': 0.002, '-e': 0.998}, 'A': {'+b +e +a': 0.95, '+b +e -a': 0.05, '+b -e +a': 0.94, '+b -e -a': 0.06, '-b +e +a': 0.29, '-b +e -a': 0.71, '-b -e +a': 0.001, '-b -e -a': 0.999}, 'J': {'+a +j': 0.9, '+a -j': 0.1, '-a +j': 0.05, '-a -j': 0.95}, 'M': {'+a +m': 0.7, '+a -m': 0.3, '-a +m': 0.01, '-a -m': 0.99}}
# ***************************************
#
# Start Extracting the Query from The File...
# Done Extracting the Query from the File.
# Extracted Query: P( B=+b| J=+j)
# Extracted Condition form the Query: B=+b|J=+j
#
# Start Extracting More Information From the Query...
# -------------------------------------------------------------------
# The Conditional Variables: B=+b
# The Dependent Variables: J=+j
# -------------------------------------------------------------------
# Extraction information for Conditional Variables From the Query...
# Final Extracted Conditional Values from the Query:
#  {'B': '+b'}
# -------------------------------------------------------------------
# Extraction information for Depended Variables From the Query...
# Final Extracted Depended Values from the Query:
#  {'J': '+j'}
# -------------------------------------------------------------------

# %% [markdown]
# ## Let's Print The Extracted Information:

# %%
print(bayesNet)
# Out:
# ------------------------------------------------------------
# Total Number of Random Variable: 5
# ------------------------------------------------------------
# All Possible Random Variable Values: {'B': ['+b', '-b'], 'E': ['+e', '-e'], 'A': ['+a', '-a'], 'J': ['+j', '-j'], 'M': ['+m', '-m']}
# ------------------------------------------------------------
# Extracted Conditional Probability Header:
# {'B': [], 'E': [], 'A': ['B', 'E'], 'J': ['A'], 'M': ['A']}
# ------------------------------------------------------------
# Extracted Conditional Probability Tables:
# {'B': {'+b': 0.001, '-b': 0.999}, 'E': {'+e': 0.002, '-e': 0.998}, 'A': {'+b +e +a': 0.95, '+b +e -a': 0.05, '+b -e +a': 0.94, '+b -e -a': 0.06, '-b +e +a': 0.29, '-b +e -a': 0.71, '-b -e +a': 0.001, '-b -e -a': 0.999}, 'J': {'+a +j': 0.9, '+a -j': 0.1, '-a +j': 0.05, '-a -j': 0.95}, 'M': {'+a +m': 0.7, '+a -m': 0.3, '-a +m': 0.01, '-a -m': 0.99}}
# ------------------------------------------------------------
# Extracted Query: P( B=+b| J=+j)
# ------------------------------------------------------------
# Extracted Condition form the Query: B=+b|J=+j
# ------------------------------------------------------------
# Final Extracted Conditional Values from the Query:
#  {'B': '+b'}
# ------------------------------------------------------------
# Final Extracted Depended Values from the Query:
#  {'J': '+j'}
# ------------------------------------------------------------

# %% [markdown]
# ## Let's See how a single sample is generated:

# %%
bayesNet.generateSample()
# Out:
# {'B': '-b', 'E': '-e', 'A': '-a', 'J': '-j', 'M': '-m'}

# %% [markdown]
# ## Now Lets Calculate the Query result using Prior Sampling Method:
# `With verbose = True`

# %%
bayesNet.doPriorSampling(TOTAL_SAMPLE = 10000, verbose = True)
# Out:
# ------------ CALCULATE THE QUERY USING PRIOR SAMPLING ------------
# Started Generating The Sample...
# ************************************
# STATUS: Iteration Number -->100<--
# Evidence Seen: 3
# Required Sample Seen: 0
# ************************************
# ************************************
# STATUS: Iteration Number -->200<--
# Evidence Seen: 10
# Required Sample Seen: 0
# ************************************
# ************************************
# STATUS: Iteration Number -->300<--
# Evidence Seen: 14
# Required Sample Seen: 0
# ************************************
# ************************************
# STATUS: Iteration Number -->400<--
# Evidence Seen: 16
# Required Sample Seen: 0
# ************************************
# ************************************
# STATUS: Iteration Number -->500<--
# Evidence Seen: 20
# Required Sample Seen: 0
# ************************************
# ************************************
# STATUS: Iteration Number -->600<--
# Evidence Seen: 28
# Required Sample Seen: 0
# ************************************
# ************************************
# STATUS: Iteration Number -->700<--
# Evidence Seen: 36
# Required Sample Seen: 0
# ************************************
# ************************************
# STATUS: Iteration Number -->800<--
# Evidence Seen: 39
# Required Sample Seen: 0
# ************************************
# ************************************
# STATUS: Iteration Number -->900<--
# Evidence Seen: 42
# Required Sample Seen: 0
# ************************************
# ************************************
# STATUS: Iteration Number -->1000<--
# Evidence Seen: 46
# Required Sample Seen: 0
# ************************************
# ************************************
# STATUS: Iteration Number -->1100<--
# Evidence Seen: 51
# Required Sample Seen: 0
# ************************************
# ************************************
# STATUS: Iteration Number -->1200<--
# Evidence Seen: 53
# Required Sample Seen: 0
# ************************************
# ************************************
# STATUS: Iteration Number -->1300<--
# Evidence Seen: 61
# Required Sample Seen: 1
# ************************************
# ************************************
# STATUS: Iteration Number -->1400<--
# Evidence Seen: 69
# Required Sample Seen: 1
# ************************************
# ************************************
# STATUS: Iteration Number -->1500<--
# Evidence Seen: 74
# Required Sample Seen: 1
# ************************************
# ************************************
# STATUS: Iteration Number -->1600<--
# Evidence Seen: 80
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->1700<--
# Evidence Seen: 85
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->1800<--
# Evidence Seen: 94
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->1900<--
# Evidence Seen: 103
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->2000<--
# Evidence Seen: 106
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->2100<--
# Evidence Seen: 108
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->2200<--
# Evidence Seen: 113
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->2300<--
# Evidence Seen: 119
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->2400<--
# Evidence Seen: 123
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->2500<--
# Evidence Seen: 130
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->2600<--
# Evidence Seen: 138
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->2700<--
# Evidence Seen: 141
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->2800<--
# Evidence Seen: 147
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->2900<--
# Evidence Seen: 148
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->3000<--
# Evidence Seen: 153
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->3100<--
# Evidence Seen: 155
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->3200<--
# Evidence Seen: 157
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->3300<--
# Evidence Seen: 159
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->3400<--
# Evidence Seen: 165
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->3500<--
# Evidence Seen: 169
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->3600<--
# Evidence Seen: 174
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->3700<--
# Evidence Seen: 179
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->3800<--
# Evidence Seen: 181
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->3900<--
# Evidence Seen: 188
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->4000<--
# Evidence Seen: 191
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->4100<--
# Evidence Seen: 196
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->4200<--
# Evidence Seen: 204
# Required Sample Seen: 3
# ************************************
# ************************************
# STATUS: Iteration Number -->4300<--
# Evidence Seen: 208
# Required Sample Seen: 3
# ************************************
# ************************************
# STATUS: Iteration Number -->4400<--
# Evidence Seen: 212
# Required Sample Seen: 3
# ************************************
# ************************************
# STATUS: Iteration Number -->4500<--
# Evidence Seen: 217
# Required Sample Seen: 3
# ************************************
# ************************************
# STATUS: Iteration Number -->4600<--
# Evidence Seen: 222
# Required Sample Seen: 3
# ************************************
# ************************************
# STATUS: Iteration Number -->4700<--
# Evidence Seen: 231
# Required Sample Seen: 4
# ************************************
# ************************************
# STATUS: Iteration Number -->4800<--
# Evidence Seen: 234
# Required Sample Seen: 4
# ************************************
# ************************************
# STATUS: Iteration Number -->4900<--
# Evidence Seen: 242
# Required Sample Seen: 4
# ************************************
# ************************************
# STATUS: Iteration Number -->5000<--
# Evidence Seen: 245
# Required Sample Seen: 5
# ************************************
# ************************************
# STATUS: Iteration Number -->5100<--
# Evidence Seen: 249
# Required Sample Seen: 5
# ************************************
# ************************************
# STATUS: Iteration Number -->5200<--
# Evidence Seen: 252
# Required Sample Seen: 5
# ************************************
# ************************************
# STATUS: Iteration Number -->5300<--
# Evidence Seen: 255
# Required Sample Seen: 5
# ************************************
# ************************************
# STATUS: Iteration Number -->5400<--
# Evidence Seen: 263
# Required Sample Seen: 5
# ************************************
# ************************************
# STATUS: Iteration Number -->5500<--
# Evidence Seen: 264
# Required Sample Seen: 5
# ************************************
# ************************************
# STATUS: Iteration Number -->5600<--
# Evidence Seen: 265
# Required Sample Seen: 5
# ************************************
# ************************************
# STATUS: Iteration Number -->5700<--
# Evidence Seen: 270
# Required Sample Seen: 5
# ************************************
# ************************************
# STATUS: Iteration Number -->5800<--
# Evidence Seen: 275
# Required Sample Seen: 5
# ************************************
# ************************************
# STATUS: Iteration Number -->5900<--
# Evidence Seen: 282
# Required Sample Seen: 5
# ************************************
# ************************************
# STATUS: Iteration Number -->6000<--
# Evidence Seen: 290
# Required Sample Seen: 5
# ************************************
# ************************************
# STATUS: Iteration Number -->6100<--
# Evidence Seen: 294
# Required Sample Seen: 5
# ************************************
# ************************************
# STATUS: Iteration Number -->6200<--
# Evidence Seen: 299
# Required Sample Seen: 5
# ************************************
# ************************************
# STATUS: Iteration Number -->6300<--
# Evidence Seen: 305
# Required Sample Seen: 5
# ************************************
# ************************************
# STATUS: Iteration Number -->6400<--
# Evidence Seen: 312
# Required Sample Seen: 5
# ************************************
# ************************************
# STATUS: Iteration Number -->6500<--
# Evidence Seen: 320
# Required Sample Seen: 5
# ************************************
# ************************************
# STATUS: Iteration Number -->6600<--
# Evidence Seen: 327
# Required Sample Seen: 6
# ************************************
# ************************************
# STATUS: Iteration Number -->6700<--
# Evidence Seen: 334
# Required Sample Seen: 6
# ************************************
# ************************************
# STATUS: Iteration Number -->6800<--
# Evidence Seen: 340
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->6900<--
# Evidence Seen: 345
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->7000<--
# Evidence Seen: 350
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->7100<--
# Evidence Seen: 353
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->7200<--
# Evidence Seen: 360
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->7300<--
# Evidence Seen: 369
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->7400<--
# Evidence Seen: 372
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->7500<--
# Evidence Seen: 375
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->7600<--
# Evidence Seen: 376
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->7700<--
# Evidence Seen: 380
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->7800<--
# Evidence Seen: 385
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->7900<--
# Evidence Seen: 391
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->8000<--
# Evidence Seen: 396
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->8100<--
# Evidence Seen: 398
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->8200<--
# Evidence Seen: 401
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->8300<--
# Evidence Seen: 405
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->8400<--
# Evidence Seen: 409
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->8500<--
# Evidence Seen: 414
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->8600<--
# Evidence Seen: 420
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->8700<--
# Evidence Seen: 424
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->8800<--
# Evidence Seen: 430
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->8900<--
# Evidence Seen: 433
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->9000<--
# Evidence Seen: 437
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->9100<--
# Evidence Seen: 443
# Required Sample Seen: 8
# ************************************
# ************************************
# STATUS: Iteration Number -->9200<--
# Evidence Seen: 451
# Required Sample Seen: 9
# ************************************
# ************************************
# STATUS: Iteration Number -->9300<--
# Evidence Seen: 454
# Required Sample Seen: 9
# ************************************
# ************************************
# STATUS: Iteration Number -->9400<--
# Evidence Seen: 458
# Required Sample Seen: 9
# ************************************
# ************************************
# STATUS: Iteration Number -->9500<--
# Evidence Seen: 462
# Required Sample Seen: 9
# ************************************
# ************************************
# STATUS: Iteration Number -->9600<--
# Evidence Seen: 467
# Required Sample Seen: 9
# ************************************
# ************************************
# STATUS: Iteration Number -->9700<--
# Evidence Seen: 471
# Required Sample Seen: 9
# ************************************
# ************************************
# STATUS: Iteration Number -->9800<--
# Evidence Seen: 475
# Required Sample Seen: 9
# ************************************
# ************************************
# STATUS: Iteration Number -->9900<--
# Evidence Seen: 480
# Required Sample Seen: 9
# ************************************
# ************************************
# STATUS: Iteration Number -->10000<--
# Evidence Seen: 482
# Required Sample Seen: 9
# ************************************
# ------------------------------------------------------------------
# Completed 10000 Iterators of Sampling.
# Final Result:
# Total Sample Generated = 10000
# Total Required Sample Seen: {'B': '+b'} | {'J': '+j'} = 9
# Total Evidence Seen: {'J': '+j'} = 482
# Probability = 0.01867219917012448
# ------------------------------------------------------------------

# %% [markdown]
# ## Now Lets Calculate the Query result using Prior Sampling Method:
# `With verbose = False`
# - Just to see the final result.

# %%
bayesNet.doPriorSampling(TOTAL_SAMPLE = 10000, verbose = False)
# Out:
# ------------ CALCULATE THE QUERY USING PRIOR SAMPLING ------------
# ------------------------------------------------------------------
# Completed 10000 Iterators of Sampling.
# Final Result:
# Total Sample Generated = 10000
# Total Required Sample Seen: {'B': '+b'} | {'J': '+j'} = 8
# Total Evidence Seen: {'J': '+j'} = 530
# Probability = 0.01509433962264151
# ------------------------------------------------------------------

# %% [markdown]
# ## Now Lets Calculate the Query result using Rejection Sampling Method:
# `With verbose = True`

# %%
bayesNet.doRejectionSampling(TOTAL_SAMPLE_REQUIRED = 10000, verbose = True)
# Out:
# ------------ CALCULATE THE QUERY USING REJECTION SAMPLING ------------
# Started Generating The Sample...
# ************************************
# STATUS: Iteration Number -->1000<--
# Total Sample Generated: 1000
# Total Sample Rejected: 934
# Total Sample Accepted: 66
# Evidence Seen: 66
# Required Sample Seen: 2
# ************************************
# ************************************
# STATUS: Iteration Number -->2000<--
# Total Sample Generated: 2000
# Total Sample Rejected: 1890
# Total Sample Accepted: 110
# Evidence Seen: 110
# Required Sample Seen: 4
# ************************************
# ************************************
# STATUS: Iteration Number -->3000<--
# Total Sample Generated: 3000
# Total Sample Rejected: 2842
# Total Sample Accepted: 158
# Evidence Seen: 158
# Required Sample Seen: 6
# ************************************
# ************************************
# STATUS: Iteration Number -->4000<--
# Total Sample Generated: 4000
# Total Sample Rejected: 3801
# Total Sample Accepted: 199
# Evidence Seen: 199
# Required Sample Seen: 6
# ************************************
# ************************************
# STATUS: Iteration Number -->5000<--
# Total Sample Generated: 5000
# Total Sample Rejected: 4742
# Total Sample Accepted: 258
# Evidence Seen: 258
# Required Sample Seen: 6
# ************************************
# ************************************
# STATUS: Iteration Number -->6000<--
# Total Sample Generated: 6000
# Total Sample Rejected: 5681
# Total Sample Accepted: 319
# Evidence Seen: 319
# Required Sample Seen: 6
# ************************************
# ************************************
# STATUS: Iteration Number -->7000<--
# Total Sample Generated: 7000
# Total Sample Rejected: 6628
# Total Sample Accepted: 372
# Evidence Seen: 372
# Required Sample Seen: 7
# ************************************
# ************************************
# STATUS: Iteration Number -->8000<--
# Total Sample Generated: 8000
# Total Sample Rejected: 7575
# Total Sample Accepted: 425
# Evidence Seen: 425
# Required Sample Seen: 8
# ************************************
# ************************************
# STATUS: Iteration Number -->9000<--
# Total Sample Generated: 9000
# Total Sample Rejected: 8506
# Total Sample Accepted: 494
# Evidence Seen: 494
# Required Sample Seen: 9
# ************************************
# ************************************
# STATUS: Iteration Number -->10000<--
# Total Sample Generated: 10000
# Total Sample Rejected: 9458
# Total Sample Accepted: 542
# Evidence Seen: 542
# Required Sample Seen: 9
# ************************************
# ************************************
# STATUS: Iteration Number -->11000<--
# Total Sample Generated: 11000
# Total Sample Rejected: 10409
# Total Sample Accepted: 591
# Evidence Seen: 591
# Required Sample Seen: 10
# ************************************
# ************************************
# STATUS: Iteration Number -->12000<--
# Total Sample Generated: 12000
# Total Sample Rejected: 11349
# Total Sample Accepted: 651
# Evidence Seen: 651
# Required Sample Seen: 10
# ************************************
# ************************************
# STATUS: Iteration Number -->13000<--
# Total Sample Generated: 13000
# Total Sample Rejected: 12289
# Total Sample Accepted: 711
# Evidence Seen: 711
# Required Sample Seen: 10
# ************************************
# ************************************
# STATUS: Iteration Number -->14000<--
# Total Sample Generated: 14000
# Total Sample Rejected: 13238
# Total Sample Accepted: 762
# Evidence Seen: 762
# Required Sample Seen: 10
# ************************************
# ************************************
# STATUS: Iteration Number -->15000<--
# Total Sample Generated: 15000
# Total Sample Rejected: 14186
# Total Sample Accepted: 814
# Evidence Seen: 814
# Required Sample Seen: 11
# ************************************
# ************************************
# STATUS: Iteration Number -->16000<--
# Total Sample Generated: 16000
# Total Sample Rejected: 15139
# Total Sample Accepted: 861
# Evidence Seen: 861
# Required Sample Seen: 12
# ************************************
# ************************************
# STATUS: Iteration Number -->17000<--
# Total Sample Generated: 17000
# Total Sample Rejected: 16087
# Total Sample Accepted: 913
# Evidence Seen: 913
# Required Sample Seen: 14
# ************************************
# ************************************
# STATUS: Iteration Number -->18000<--
# Total Sample Generated: 18000
# Total Sample Rejected: 17036
# Total Sample Accepted: 964
# Evidence Seen: 964
# Required Sample Seen: 14
# ************************************
# ************************************
# STATUS: Iteration Number -->19000<--
# Total Sample Generated: 19000
# Total Sample Rejected: 17976
# Total Sample Accepted: 1024
# Evidence Seen: 1024
# Required Sample Seen: 14
# ************************************
# ************************************
# STATUS: Iteration Number -->20000<--
# Total Sample Generated: 20000
# Total Sample Rejected: 18912
# Total Sample Accepted: 1088
# Evidence Seen: 1088
# Required Sample Seen: 15
# ************************************
# ************************************
# STATUS: Iteration Number -->21000<--
# Total Sample Generated: 21000
# Total Sample Rejected: 19858
# Total Sample Accepted: 1142
# Evidence Seen: 1142
# Required Sample Seen: 15
# ************************************
# ************************************
# STATUS: Iteration Number -->22000<--
# Total Sample Generated: 22000
# Total Sample Rejected: 20801
# Total Sample Accepted: 1199
# Evidence Seen: 1199
# Required Sample Seen: 15
# ************************************
# ************************************
# STATUS: Iteration Number -->23000<--
# Total Sample Generated: 23000
# Total Sample Rejected: 21743
# Total Sample Accepted: 1257
# Evidence Seen: 1257
# Required Sample Seen: 17
# ************************************
# ************************************
# STATUS: Iteration Number -->24000<--
# Total Sample Generated: 24000
# Total Sample Rejected: 22684
# Total Sample Accepted: 1316
# Evidence Seen: 1316
# Required Sample Seen: 18
# ************************************
# ************************************
# STATUS: Iteration Number -->25000<--
# Total Sample Generated: 25000
# Total Sample Rejected: 23636
# Total Sample Accepted: 1364
# Evidence Seen: 1364
# Required Sample Seen: 18
# ************************************
# ************************************
# STATUS: Iteration Number -->26000<--
# Total Sample Generated: 26000
# Total Sample Rejected: 24582
# Total Sample Accepted: 1418
# Evidence Seen: 1418
# Required Sample Seen: 19
# ************************************
# ************************************
# STATUS: Iteration Number -->27000<--
# Total Sample Generated: 27000
# Total Sample Rejected: 25535
# Total Sample Accepted: 1465
# Evidence Seen: 1465
# Required Sample Seen: 21
# ************************************
# ************************************
# STATUS: Iteration Number -->28000<--
# Total Sample Generated: 28000
# Total Sample Rejected: 26488
# Total Sample Accepted: 1512
# Evidence Seen: 1512
# Required Sample Seen: 22
# ************************************
# ************************************
# STATUS: Iteration Number -->29000<--
# Total Sample Generated: 29000
# Total Sample Rejected: 27427
# Total Sample Accepted: 1573
# Evidence Seen: 1573
# Required Sample Seen: 23
# ************************************
# ************************************
# STATUS: Iteration Number -->30000<--
# Total Sample Generated: 30000
# Total Sample Rejected: 28380
# Total Sample Accepted: 1620
# Evidence Seen: 1620
# Required Sample Seen: 24
# ************************************
# ************************************
# STATUS: Iteration Number -->31000<--
# Total Sample Generated: 31000
# Total Sample Rejected: 29315
# Total Sample Accepted: 1685
# Evidence Seen: 1685
# Required Sample Seen: 25
# ************************************
# ************************************
# STATUS: Iteration Number -->32000<--
# Total Sample Generated: 32000
# Total Sample Rejected: 30271
# Total Sample Accepted: 1729
# Evidence Seen: 1729
# Required Sample Seen: 26
# ************************************
# ************************************
# STATUS: Iteration Number -->33000<--
# Total Sample Generated: 33000
# Total Sample Rejected: 31216
# Total Sample Accepted: 1784
# Evidence Seen: 1784
# Required Sample Seen: 27
# ************************************
# ************************************
# STATUS: Iteration Number -->34000<--
# Total Sample Generated: 34000
# Total Sample Rejected: 32162
# Total Sample Accepted: 1838
# Evidence Seen: 1838
# Required Sample Seen: 27
# ************************************
# ************************************
# STATUS: Iteration Number -->35000<--
# Total Sample Generated: 35000
# Total Sample Rejected: 33109
# Total Sample Accepted: 1891
# Evidence Seen: 1891
# Required Sample Seen: 28
# ************************************
# ************************************
# STATUS: Iteration Number -->36000<--
# Total Sample Generated: 36000
# Total Sample Rejected: 34055
# Total Sample Accepted: 1945
# Evidence Seen: 1945
# Required Sample Seen: 29
# ************************************
# ************************************
# STATUS: Iteration Number -->37000<--
# Total Sample Generated: 37000
# Total Sample Rejected: 34990
# Total Sample Accepted: 2010
# Evidence Seen: 2010
# Required Sample Seen: 29
# ************************************
# ************************************
# STATUS: Iteration Number -->38000<--
# Total Sample Generated: 38000
# Total Sample Rejected: 35947
# Total Sample Accepted: 2053
# Evidence Seen: 2053
# Required Sample Seen: 29
# ************************************
# ************************************
# STATUS: Iteration Number -->39000<--
# Total Sample Generated: 39000
# Total Sample Rejected: 36902
# Total Sample Accepted: 2098
# Evidence Seen: 2098
# Required Sample Seen: 29
# ************************************
# ************************************
# STATUS: Iteration Number -->40000<--
# Total Sample Generated: 40000
# Total Sample Rejected: 37856
# Total Sample Accepted: 2144
# Evidence Seen: 2144
# Required Sample Seen: 29
# ************************************
# ************************************
# STATUS: Iteration Number -->41000<--
# Total Sample Generated: 41000
# Total Sample Rejected: 38799
# Total Sample Accepted: 2201
# Evidence Seen: 2201
# Required Sample Seen: 29
# ************************************
# ************************************
# STATUS: Iteration Number -->42000<--
# Total Sample Generated: 42000
# Total Sample Rejected: 39748
# Total Sample Accepted: 2252
# Evidence Seen: 2252
# Required Sample Seen: 31
# ************************************
# ************************************
# STATUS: Iteration Number -->43000<--
# Total Sample Generated: 43000
# Total Sample Rejected: 40687
# Total Sample Accepted: 2313
# Evidence Seen: 2313
# Required Sample Seen: 33
# ************************************
# ************************************
# STATUS: Iteration Number -->44000<--
# Total Sample Generated: 44000
# Total Sample Rejected: 41637
# Total Sample Accepted: 2363
# Evidence Seen: 2363
# Required Sample Seen: 33
# ************************************
# ************************************
# STATUS: Iteration Number -->45000<--
# Total Sample Generated: 45000
# Total Sample Rejected: 42584
# Total Sample Accepted: 2416
# Evidence Seen: 2416
# Required Sample Seen: 34
# ************************************
# ************************************
# STATUS: Iteration Number -->46000<--
# Total Sample Generated: 46000
# Total Sample Rejected: 43539
# Total Sample Accepted: 2461
# Evidence Seen: 2461
# Required Sample Seen: 34
# ************************************
# ************************************
# STATUS: Iteration Number -->47000<--
# Total Sample Generated: 47000
# Total Sample Rejected: 44496
# Total Sample Accepted: 2504
# Evidence Seen: 2504
# Required Sample Seen: 34
# ************************************
# ************************************
# STATUS: Iteration Number -->48000<--
# Total Sample Generated: 48000
# Total Sample Rejected: 45442
# Total Sample Accepted: 2558
# Evidence Seen: 2558
# Required Sample Seen: 35
# ************************************
# ************************************
# STATUS: Iteration Number -->49000<--
# Total Sample Generated: 49000
# Total Sample Rejected: 46391
# Total Sample Accepted: 2609
# Evidence Seen: 2609
# Required Sample Seen: 37
# ************************************
# ************************************
# STATUS: Iteration Number -->50000<--
# Total Sample Generated: 50000
# Total Sample Rejected: 47340
# Total Sample Accepted: 2660
# Evidence Seen: 2660
# Required Sample Seen: 38
# ************************************
# ************************************
# STATUS: Iteration Number -->51000<--
# Total Sample Generated: 51000
# Total Sample Rejected: 48292
# Total Sample Accepted: 2708
# Evidence Seen: 2708
# Required Sample Seen: 40
# ************************************
# ************************************
# STATUS: Iteration Number -->52000<--
# Total Sample Generated: 52000
# Total Sample Rejected: 49240
# Total Sample Accepted: 2760
# Evidence Seen: 2760
# Required Sample Seen: 44
# ************************************
# ************************************
# STATUS: Iteration Number -->53000<--
# Total Sample Generated: 53000
# Total Sample Rejected: 50185
# Total Sample Accepted: 2815
# Evidence Seen: 2815
# Required Sample Seen: 44
# ************************************
# ************************************
# STATUS: Iteration Number -->54000<--
# Total Sample Generated: 54000
# Total Sample Rejected: 51143
# Total Sample Accepted: 2857
# Evidence Seen: 2857
# Required Sample Seen: 44
# ************************************
# ************************************
# STATUS: Iteration Number -->55000<--
# Total Sample Generated: 55000
# Total Sample Rejected: 52085
# Total Sample Accepted: 2915
# Evidence Seen: 2915
# Required Sample Seen: 45
# ************************************
# ************************************
# STATUS: Iteration Number -->56000<--
# Total Sample Generated: 56000
# Total Sample Rejected: 53031
# Total Sample Accepted: 2969
# Evidence Seen: 2969
# Required Sample Seen: 45
# ************************************
# ************************************
# STATUS: Iteration Number -->57000<--
# Total Sample Generated: 57000
# Total Sample Rejected: 53978
# Total Sample Accepted: 3022
# Evidence Seen: 3022
# Required Sample Seen: 45
# ************************************
# ************************************
# STATUS: Iteration Number -->58000<--
# Total Sample Generated: 58000
# Total Sample Rejected: 54931
# Total Sample Accepted: 3069
# Evidence Seen: 3069
# Required Sample Seen: 45
# ************************************
# ************************************
# STATUS: Iteration Number -->59000<--
# Total Sample Generated: 59000
# Total Sample Rejected: 55878
# Total Sample Accepted: 3122
# Evidence Seen: 3122
# Required Sample Seen: 46
# ************************************
# ************************************
# STATUS: Iteration Number -->60000<--
# Total Sample Generated: 60000
# Total Sample Rejected: 56816
# Total Sample Accepted: 3184
# Evidence Seen: 3184
# Required Sample Seen: 48
# ************************************
# ************************************
# STATUS: Iteration Number -->61000<--
# Total Sample Generated: 61000
# Total Sample Rejected: 57767
# Total Sample Accepted: 3233
# Evidence Seen: 3233
# Required Sample Seen: 48
# ************************************
# ************************************
# STATUS: Iteration Number -->62000<--
# Total Sample Generated: 62000
# Total Sample Rejected: 58713
# Total Sample Accepted: 3287
# Evidence Seen: 3287
# Required Sample Seen: 48
# ************************************
# ************************************
# STATUS: Iteration Number -->63000<--
# Total Sample Generated: 63000
# Total Sample Rejected: 59663
# Total Sample Accepted: 3337
# Evidence Seen: 3337
# Required Sample Seen: 48
# ************************************
# ************************************
# STATUS: Iteration Number -->64000<--
# Total Sample Generated: 64000
# Total Sample Rejected: 60599
# Total Sample Accepted: 3401
# Evidence Seen: 3401
# Required Sample Seen: 50
# ************************************
# ************************************
# STATUS: Iteration Number -->65000<--
# Total Sample Generated: 65000
# Total Sample Rejected: 61552
# Total Sample Accepted: 3448
# Evidence Seen: 3448
# Required Sample Seen: 52
# ************************************
# ************************************
# STATUS: Iteration Number -->66000<--
# Total Sample Generated: 66000
# Total Sample Rejected: 62504
# Total Sample Accepted: 3496
# Evidence Seen: 3496
# Required Sample Seen: 53
# ************************************
# ************************************
# STATUS: Iteration Number -->67000<--
# Total Sample Generated: 67000
# Total Sample Rejected: 63449
# Total Sample Accepted: 3551
# Evidence Seen: 3551
# Required Sample Seen: 53
# ************************************
# ************************************
# STATUS: Iteration Number -->68000<--
# Total Sample Generated: 68000
# Total Sample Rejected: 64400
# Total Sample Accepted: 3600
# Evidence Seen: 3600
# Required Sample Seen: 54
# ************************************
# ************************************
# STATUS: Iteration Number -->69000<--
# Total Sample Generated: 69000
# Total Sample Rejected: 65358
# Total Sample Accepted: 3642
# Evidence Seen: 3642
# Required Sample Seen: 54
# ************************************
# ************************************
# STATUS: Iteration Number -->70000<--
# Total Sample Generated: 70000
# Total Sample Rejected: 66320
# Total Sample Accepted: 3680
# Evidence Seen: 3680
# Required Sample Seen: 54
# ************************************
# ************************************
# STATUS: Iteration Number -->71000<--
# Total Sample Generated: 71000
# Total Sample Rejected: 67262
# Total Sample Accepted: 3738
# Evidence Seen: 3738
# Required Sample Seen: 55
# ************************************
# ************************************
# STATUS: Iteration Number -->72000<--
# Total Sample Generated: 72000
# Total Sample Rejected: 68217
# Total Sample Accepted: 3783
# Evidence Seen: 3783
# Required Sample Seen: 55
# ************************************
# ************************************
# STATUS: Iteration Number -->73000<--
# Total Sample Generated: 73000
# Total Sample Rejected: 69159
# Total Sample Accepted: 3841
# Evidence Seen: 3841
# Required Sample Seen: 58
# ************************************
# ************************************
# STATUS: Iteration Number -->74000<--
# Total Sample Generated: 74000
# Total Sample Rejected: 70108
# Total Sample Accepted: 3892
# Evidence Seen: 3892
# Required Sample Seen: 58
# ************************************
# ************************************
# STATUS: Iteration Number -->75000<--
# Total Sample Generated: 75000
# Total Sample Rejected: 71068
# Total Sample Accepted: 3932
# Evidence Seen: 3932
# Required Sample Seen: 59
# ************************************
# ************************************
# STATUS: Iteration Number -->76000<--
# Total Sample Generated: 76000
# Total Sample Rejected: 72005
# Total Sample Accepted: 3995
# Evidence Seen: 3995
# Required Sample Seen: 59
# ************************************
# ************************************
# STATUS: Iteration Number -->77000<--
# Total Sample Generated: 77000
# Total Sample Rejected: 72959
# Total Sample Accepted: 4041
# Evidence Seen: 4041
# Required Sample Seen: 59
# ************************************
# ************************************
# STATUS: Iteration Number -->78000<--
# Total Sample Generated: 78000
# Total Sample Rejected: 73907
# Total Sample Accepted: 4093
# Evidence Seen: 4093
# Required Sample Seen: 59
# ************************************
# ************************************
# STATUS: Iteration Number -->79000<--
# Total Sample Generated: 79000
# Total Sample Rejected: 74863
# Total Sample Accepted: 4137
# Evidence Seen: 4137
# Required Sample Seen: 59
# ************************************
# ************************************
# STATUS: Iteration Number -->80000<--
# Total Sample Generated: 80000
# Total Sample Rejected: 75806
# Total Sample Accepted: 4194
# Evidence Seen: 4194
# Required Sample Seen: 60
# ************************************
# ************************************
# STATUS: Iteration Number -->81000<--
# Total Sample Generated: 81000
# Total Sample Rejected: 76750
# Total Sample Accepted: 4250
# Evidence Seen: 4250
# Required Sample Seen: 61
# ************************************
# ************************************
# STATUS: Iteration Number -->82000<--
# Total Sample Generated: 82000
# Total Sample Rejected: 77705
# Total Sample Accepted: 4295
# Evidence Seen: 4295
# Required Sample Seen: 64
# ************************************
# ************************************
# STATUS: Iteration Number -->83000<--
# Total Sample Generated: 83000
# Total Sample Rejected: 78658
# Total Sample Accepted: 4342
# Evidence Seen: 4342
# Required Sample Seen: 65
# ************************************
# ************************************
# STATUS: Iteration Number -->84000<--
# Total Sample Generated: 84000
# Total Sample Rejected: 79620
# Total Sample Accepted: 4380
# Evidence Seen: 4380
# Required Sample Seen: 66
# ************************************
# ************************************
# STATUS: Iteration Number -->85000<--
# Total Sample Generated: 85000
# Total Sample Rejected: 80577
# Total Sample Accepted: 4423
# Evidence Seen: 4423
# Required Sample Seen: 66
# ************************************
# ************************************
# STATUS: Iteration Number -->86000<--
# Total Sample Generated: 86000
# Total Sample Rejected: 81520
# Total Sample Accepted: 4480
# Evidence Seen: 4480
# Required Sample Seen: 66
# ************************************
# ************************************
# STATUS: Iteration Number -->87000<--
# Total Sample Generated: 87000
# Total Sample Rejected: 82476
# Total Sample Accepted: 4524
# Evidence Seen: 4524
# Required Sample Seen: 68
# ************************************
# ************************************
# STATUS: Iteration Number -->88000<--
# Total Sample Generated: 88000
# Total Sample Rejected: 83432
# Total Sample Accepted: 4568
# Evidence Seen: 4568
# Required Sample Seen: 68
# ************************************
# ************************************
# STATUS: Iteration Number -->89000<--
# Total Sample Generated: 89000
# Total Sample Rejected: 84390
# Total Sample Accepted: 4610
# Evidence Seen: 4610
# Required Sample Seen: 68
# ************************************
# ************************************
# STATUS: Iteration Number -->90000<--
# Total Sample Generated: 90000
# Total Sample Rejected: 85337
# Total Sample Accepted: 4663
# Evidence Seen: 4663
# Required Sample Seen: 69
# ************************************
# ************************************
# STATUS: Iteration Number -->91000<--
# Total Sample Generated: 91000
# Total Sample Rejected: 86295
# Total Sample Accepted: 4705
# Evidence Seen: 4705
# Required Sample Seen: 70
# ************************************
# ************************************
# STATUS: Iteration Number -->92000<--
# Total Sample Generated: 92000
# Total Sample Rejected: 87233
# Total Sample Accepted: 4767
# Evidence Seen: 4767
# Required Sample Seen: 73
# ************************************
# ************************************
# STATUS: Iteration Number -->93000<--
# Total Sample Generated: 93000
# Total Sample Rejected: 88193
# Total Sample Accepted: 4807
# Evidence Seen: 4807
# Required Sample Seen: 73
# ************************************
# ************************************
# STATUS: Iteration Number -->94000<--
# Total Sample Generated: 94000
# Total Sample Rejected: 89152
# Total Sample Accepted: 4848
# Evidence Seen: 4848
# Required Sample Seen: 73
# ************************************
# ************************************
# STATUS: Iteration Number -->95000<--
# Total Sample Generated: 95000
# Total Sample Rejected: 90091
# Total Sample Accepted: 4909
# Evidence Seen: 4909
# Required Sample Seen: 74
# ************************************
# ************************************
# STATUS: Iteration Number -->96000<--
# Total Sample Generated: 96000
# Total Sample Rejected: 91044
# Total Sample Accepted: 4956
# Evidence Seen: 4956
# Required Sample Seen: 75
# ************************************
# ************************************
# STATUS: Iteration Number -->97000<--
# Total Sample Generated: 97000
# Total Sample Rejected: 91981
# Total Sample Accepted: 5019
# Evidence Seen: 5019
# Required Sample Seen: 77
# ************************************
# ************************************
# STATUS: Iteration Number -->98000<--
# Total Sample Generated: 98000
# Total Sample Rejected: 92915
# Total Sample Accepted: 5085
# Evidence Seen: 5085
# Required Sample Seen: 77
# ************************************
# ************************************
# STATUS: Iteration Number -->99000<--
# Total Sample Generated: 99000
# Total Sample Rejected: 93850
# Total Sample Accepted: 5150
# Evidence Seen: 5150
# Required Sample Seen: 79
# ************************************
# ************************************
# STATUS: Iteration Number -->100000<--
# Total Sample Generated: 100000
# Total Sample Rejected: 94807
# Total Sample Accepted: 5193
# Evidence Seen: 5193
# Required Sample Seen: 79
# ************************************
# ************************************
# STATUS: Iteration Number -->101000<--
# Total Sample Generated: 101000
# Total Sample Rejected: 95751
# Total Sample Accepted: 5249
# Evidence Seen: 5249
# Required Sample Seen: 79
# ************************************
# ************************************
# STATUS: Iteration Number -->102000<--
# Total Sample Generated: 102000
# Total Sample Rejected: 96691
# Total Sample Accepted: 5309
# Evidence Seen: 5309
# Required Sample Seen: 79
# ************************************
# ************************************
# STATUS: Iteration Number -->103000<--
# Total Sample Generated: 103000
# Total Sample Rejected: 97637
# Total Sample Accepted: 5363
# Evidence Seen: 5363
# Required Sample Seen: 81
# ************************************
# ************************************
# STATUS: Iteration Number -->104000<--
# Total Sample Generated: 104000
# Total Sample Rejected: 98579
# Total Sample Accepted: 5421
# Evidence Seen: 5421
# Required Sample Seen: 81
# ************************************
# ************************************
# STATUS: Iteration Number -->105000<--
# Total Sample Generated: 105000
# Total Sample Rejected: 99534
# Total Sample Accepted: 5466
# Evidence Seen: 5466
# Required Sample Seen: 81
# ************************************
# ************************************
# STATUS: Iteration Number -->106000<--
# Total Sample Generated: 106000
# Total Sample Rejected: 100481
# Total Sample Accepted: 5519
# Evidence Seen: 5519
# Required Sample Seen: 83
# ************************************
# ************************************
# STATUS: Iteration Number -->107000<--
# Total Sample Generated: 107000
# Total Sample Rejected: 101428
# Total Sample Accepted: 5572
# Evidence Seen: 5572
# Required Sample Seen: 84
# ************************************
# ************************************
# STATUS: Iteration Number -->108000<--
# Total Sample Generated: 108000
# Total Sample Rejected: 102368
# Total Sample Accepted: 5632
# Evidence Seen: 5632
# Required Sample Seen: 86
# ************************************
# ************************************
# STATUS: Iteration Number -->109000<--
# Total Sample Generated: 109000
# Total Sample Rejected: 103314
# Total Sample Accepted: 5686
# Evidence Seen: 5686
# Required Sample Seen: 86
# ************************************
# ************************************
# STATUS: Iteration Number -->110000<--
# Total Sample Generated: 110000
# Total Sample Rejected: 104251
# Total Sample Accepted: 5749
# Evidence Seen: 5749
# Required Sample Seen: 88
# ************************************
# ************************************
# STATUS: Iteration Number -->111000<--
# Total Sample Generated: 111000
# Total Sample Rejected: 105200
# Total Sample Accepted: 5800
# Evidence Seen: 5800
# Required Sample Seen: 88
# ************************************
# ************************************
# STATUS: Iteration Number -->112000<--
# Total Sample Generated: 112000
# Total Sample Rejected: 106153
# Total Sample Accepted: 5847
# Evidence Seen: 5847
# Required Sample Seen: 89
# ************************************
# ************************************
# STATUS: Iteration Number -->113000<--
# Total Sample Generated: 113000
# Total Sample Rejected: 107098
# Total Sample Accepted: 5902
# Evidence Seen: 5902
# Required Sample Seen: 90
# ************************************
# ************************************
# STATUS: Iteration Number -->114000<--
# Total Sample Generated: 114000
# Total Sample Rejected: 108056
# Total Sample Accepted: 5944
# Evidence Seen: 5944
# Required Sample Seen: 91
# ************************************
# ************************************
# STATUS: Iteration Number -->115000<--
# Total Sample Generated: 115000
# Total Sample Rejected: 109002
# Total Sample Accepted: 5998
# Evidence Seen: 5998
# Required Sample Seen: 91
# ************************************
# ************************************
# STATUS: Iteration Number -->116000<--
# Total Sample Generated: 116000
# Total Sample Rejected: 109945
# Total Sample Accepted: 6055
# Evidence Seen: 6055
# Required Sample Seen: 91
# ************************************
# ************************************
# STATUS: Iteration Number -->117000<--
# Total Sample Generated: 117000
# Total Sample Rejected: 110888
# Total Sample Accepted: 6112
# Evidence Seen: 6112
# Required Sample Seen: 92
# ************************************
# ************************************
# STATUS: Iteration Number -->118000<--
# Total Sample Generated: 118000
# Total Sample Rejected: 111839
# Total Sample Accepted: 6161
# Evidence Seen: 6161
# Required Sample Seen: 92
# ************************************
# ************************************
# STATUS: Iteration Number -->119000<--
# Total Sample Generated: 119000
# Total Sample Rejected: 112791
# Total Sample Accepted: 6209
# Evidence Seen: 6209
# Required Sample Seen: 92
# ************************************
# ************************************
# STATUS: Iteration Number -->120000<--
# Total Sample Generated: 120000
# Total Sample Rejected: 113734
# Total Sample Accepted: 6266
# Evidence Seen: 6266
# Required Sample Seen: 92
# ************************************
# ************************************
# STATUS: Iteration Number -->121000<--
# Total Sample Generated: 121000
# Total Sample Rejected: 114681
# Total Sample Accepted: 6319
# Evidence Seen: 6319
# Required Sample Seen: 93
# ************************************
# ************************************
# STATUS: Iteration Number -->122000<--
# Total Sample Generated: 122000
# Total Sample Rejected: 115632
# Total Sample Accepted: 6368
# Evidence Seen: 6368
# Required Sample Seen: 94
# ************************************
# ************************************
# STATUS: Iteration Number -->123000<--
# Total Sample Generated: 123000
# Total Sample Rejected: 116593
# Total Sample Accepted: 6407
# Evidence Seen: 6407
# Required Sample Seen: 94
# ************************************
# ************************************
# STATUS: Iteration Number -->124000<--
# Total Sample Generated: 124000
# Total Sample Rejected: 117546
# Total Sample Accepted: 6454
# Evidence Seen: 6454
# Required Sample Seen: 96
# ************************************
# ************************************
# STATUS: Iteration Number -->125000<--
# Total Sample Generated: 125000
# Total Sample Rejected: 118493
# Total Sample Accepted: 6507
# Evidence Seen: 6507
# Required Sample Seen: 97
# ************************************
# ************************************
# STATUS: Iteration Number -->126000<--
# Total Sample Generated: 126000
# Total Sample Rejected: 119431
# Total Sample Accepted: 6569
# Evidence Seen: 6569
# Required Sample Seen: 97
# ************************************
# ************************************
# STATUS: Iteration Number -->127000<--
# Total Sample Generated: 127000
# Total Sample Rejected: 120383
# Total Sample Accepted: 6617
# Evidence Seen: 6617
# Required Sample Seen: 97
# ************************************
# ************************************
# STATUS: Iteration Number -->128000<--
# Total Sample Generated: 128000
# Total Sample Rejected: 121333
# Total Sample Accepted: 6667
# Evidence Seen: 6667
# Required Sample Seen: 97
# ************************************
# ************************************
# STATUS: Iteration Number -->129000<--
# Total Sample Generated: 129000
# Total Sample Rejected: 122285
# Total Sample Accepted: 6715
# Evidence Seen: 6715
# Required Sample Seen: 97
# ************************************
# ************************************
# STATUS: Iteration Number -->130000<--
# Total Sample Generated: 130000
# Total Sample Rejected: 123226
# Total Sample Accepted: 6774
# Evidence Seen: 6774
# Required Sample Seen: 98
# ************************************
# ************************************
# STATUS: Iteration Number -->131000<--
# Total Sample Generated: 131000
# Total Sample Rejected: 124171
# Total Sample Accepted: 6829
# Evidence Seen: 6829
# Required Sample Seen: 100
# ************************************
# ************************************
# STATUS: Iteration Number -->132000<--
# Total Sample Generated: 132000
# Total Sample Rejected: 125122
# Total Sample Accepted: 6878
# Evidence Seen: 6878
# Required Sample Seen: 100
# ************************************
# ************************************
# STATUS: Iteration Number -->133000<--
# Total Sample Generated: 133000
# Total Sample Rejected: 126075
# Total Sample Accepted: 6925
# Evidence Seen: 6925
# Required Sample Seen: 101
# ************************************
# ************************************
# STATUS: Iteration Number -->134000<--
# Total Sample Generated: 134000
# Total Sample Rejected: 127032
# Total Sample Accepted: 6968
# Evidence Seen: 6968
# Required Sample Seen: 103
# ************************************
# ************************************
# STATUS: Iteration Number -->135000<--
# Total Sample Generated: 135000
# Total Sample Rejected: 127981
# Total Sample Accepted: 7019
# Evidence Seen: 7019
# Required Sample Seen: 104
# ************************************
# ************************************
# STATUS: Iteration Number -->136000<--
# Total Sample Generated: 136000
# Total Sample Rejected: 128921
# Total Sample Accepted: 7079
# Evidence Seen: 7079
# Required Sample Seen: 106
# ************************************
# ************************************
# STATUS: Iteration Number -->137000<--
# Total Sample Generated: 137000
# Total Sample Rejected: 129869
# Total Sample Accepted: 7131
# Evidence Seen: 7131
# Required Sample Seen: 106
# ************************************
# ************************************
# STATUS: Iteration Number -->138000<--
# Total Sample Generated: 138000
# Total Sample Rejected: 130817
# Total Sample Accepted: 7183
# Evidence Seen: 7183
# Required Sample Seen: 107
# ************************************
# ************************************
# STATUS: Iteration Number -->139000<--
# Total Sample Generated: 139000
# Total Sample Rejected: 131769
# Total Sample Accepted: 7231
# Evidence Seen: 7231
# Required Sample Seen: 107
# ************************************
# ************************************
# STATUS: Iteration Number -->140000<--
# Total Sample Generated: 140000
# Total Sample Rejected: 132706
# Total Sample Accepted: 7294
# Evidence Seen: 7294
# Required Sample Seen: 108
# ************************************
# ************************************
# STATUS: Iteration Number -->141000<--
# Total Sample Generated: 141000
# Total Sample Rejected: 133649
# Total Sample Accepted: 7351
# Evidence Seen: 7351
# Required Sample Seen: 108
# ************************************
# ************************************
# STATUS: Iteration Number -->142000<--
# Total Sample Generated: 142000
# Total Sample Rejected: 134595
# Total Sample Accepted: 7405
# Evidence Seen: 7405
# Required Sample Seen: 109
# ************************************
# ************************************
# STATUS: Iteration Number -->143000<--
# Total Sample Generated: 143000
# Total Sample Rejected: 135532
# Total Sample Accepted: 7468
# Evidence Seen: 7468
# Required Sample Seen: 110
# ************************************
# ************************************
# STATUS: Iteration Number -->144000<--
# Total Sample Generated: 144000
# Total Sample Rejected: 136482
# Total Sample Accepted: 7518
# Evidence Seen: 7518
# Required Sample Seen: 114
# ************************************
# ************************************
# STATUS: Iteration Number -->145000<--
# Total Sample Generated: 145000
# Total Sample Rejected: 137439
# Total Sample Accepted: 7561
# Evidence Seen: 7561
# Required Sample Seen: 114
# ************************************
# ************************************
# STATUS: Iteration Number -->146000<--
# Total Sample Generated: 146000
# Total Sample Rejected: 138387
# Total Sample Accepted: 7613
# Evidence Seen: 7613
# Required Sample Seen: 115
# ************************************
# ************************************
# STATUS: Iteration Number -->147000<--
# Total Sample Generated: 147000
# Total Sample Rejected: 139345
# Total Sample Accepted: 7655
# Evidence Seen: 7655
# Required Sample Seen: 115
# ************************************
# ************************************
# STATUS: Iteration Number -->148000<--
# Total Sample Generated: 148000
# Total Sample Rejected: 140280
# Total Sample Accepted: 7720
# Evidence Seen: 7720
# Required Sample Seen: 119
# ************************************
# ************************************
# STATUS: Iteration Number -->149000<--
# Total Sample Generated: 149000
# Total Sample Rejected: 141238
# Total Sample Accepted: 7762
# Evidence Seen: 7762
# Required Sample Seen: 119
# ************************************
# ************************************
# STATUS: Iteration Number -->150000<--
# Total Sample Generated: 150000
# Total Sample Rejected: 142184
# Total Sample Accepted: 7816
# Evidence Seen: 7816
# Required Sample Seen: 119
# ************************************
# ************************************
# STATUS: Iteration Number -->151000<--
# Total Sample Generated: 151000
# Total Sample Rejected: 143132
# Total Sample Accepted: 7868
# Evidence Seen: 7868
# Required Sample Seen: 121
# ************************************
# ************************************
# STATUS: Iteration Number -->152000<--
# Total Sample Generated: 152000
# Total Sample Rejected: 144081
# Total Sample Accepted: 7919
# Evidence Seen: 7919
# Required Sample Seen: 122
# ************************************
# ************************************
# STATUS: Iteration Number -->153000<--
# Total Sample Generated: 153000
# Total Sample Rejected: 145035
# Total Sample Accepted: 7965
# Evidence Seen: 7965
# Required Sample Seen: 125
# ************************************
# ************************************
# STATUS: Iteration Number -->154000<--
# Total Sample Generated: 154000
# Total Sample Rejected: 145983
# Total Sample Accepted: 8017
# Evidence Seen: 8017
# Required Sample Seen: 125
# ************************************
# ************************************
# STATUS: Iteration Number -->155000<--
# Total Sample Generated: 155000
# Total Sample Rejected: 146929
# Total Sample Accepted: 8071
# Evidence Seen: 8071
# Required Sample Seen: 130
# ************************************
# ************************************
# STATUS: Iteration Number -->156000<--
# Total Sample Generated: 156000
# Total Sample Rejected: 147888
# Total Sample Accepted: 8112
# Evidence Seen: 8112
# Required Sample Seen: 130
# ************************************
# ************************************
# STATUS: Iteration Number -->157000<--
# Total Sample Generated: 157000
# Total Sample Rejected: 148827
# Total Sample Accepted: 8173
# Evidence Seen: 8173
# Required Sample Seen: 130
# ************************************
# ************************************
# STATUS: Iteration Number -->158000<--
# Total Sample Generated: 158000
# Total Sample Rejected: 149777
# Total Sample Accepted: 8223
# Evidence Seen: 8223
# Required Sample Seen: 133
# ************************************
# ************************************
# STATUS: Iteration Number -->159000<--
# Total Sample Generated: 159000
# Total Sample Rejected: 150747
# Total Sample Accepted: 8253
# Evidence Seen: 8253
# Required Sample Seen: 135
# ************************************
# ************************************
# STATUS: Iteration Number -->160000<--
# Total Sample Generated: 160000
# Total Sample Rejected: 151685
# Total Sample Accepted: 8315
# Evidence Seen: 8315
# Required Sample Seen: 136
# ************************************
# ************************************
# STATUS: Iteration Number -->161000<--
# Total Sample Generated: 161000
# Total Sample Rejected: 152631
# Total Sample Accepted: 8369
# Evidence Seen: 8369
# Required Sample Seen: 139
# ************************************
# ************************************
# STATUS: Iteration Number -->162000<--
# Total Sample Generated: 162000
# Total Sample Rejected: 153589
# Total Sample Accepted: 8411
# Evidence Seen: 8411
# Required Sample Seen: 140
# ************************************
# ************************************
# STATUS: Iteration Number -->163000<--
# Total Sample Generated: 163000
# Total Sample Rejected: 154542
# Total Sample Accepted: 8458
# Evidence Seen: 8458
# Required Sample Seen: 140
# ************************************
# ************************************
# STATUS: Iteration Number -->164000<--
# Total Sample Generated: 164000
# Total Sample Rejected: 155497
# Total Sample Accepted: 8503
# Evidence Seen: 8503
# Required Sample Seen: 141
# ************************************
# ************************************
# STATUS: Iteration Number -->165000<--
# Total Sample Generated: 165000
# Total Sample Rejected: 156453
# Total Sample Accepted: 8547
# Evidence Seen: 8547
# Required Sample Seen: 142
# ************************************
# ************************************
# STATUS: Iteration Number -->166000<--
# Total Sample Generated: 166000
# Total Sample Rejected: 157395
# Total Sample Accepted: 8605
# Evidence Seen: 8605
# Required Sample Seen: 143
# ************************************
# ************************************
# STATUS: Iteration Number -->167000<--
# Total Sample Generated: 167000
# Total Sample Rejected: 158347
# Total Sample Accepted: 8653
# Evidence Seen: 8653
# Required Sample Seen: 144
# ************************************
# ************************************
# STATUS: Iteration Number -->168000<--
# Total Sample Generated: 168000
# Total Sample Rejected: 159307
# Total Sample Accepted: 8693
# Evidence Seen: 8693
# Required Sample Seen: 145
# ************************************
# ************************************
# STATUS: Iteration Number -->169000<--
# Total Sample Generated: 169000
# Total Sample Rejected: 160255
# Total Sample Accepted: 8745
# Evidence Seen: 8745
# Required Sample Seen: 145
# ************************************
# ************************************
# STATUS: Iteration Number -->170000<--
# Total Sample Generated: 170000
# Total Sample Rejected: 161206
# Total Sample Accepted: 8794
# Evidence Seen: 8794
# Required Sample Seen: 145
# ************************************
# ************************************
# STATUS: Iteration Number -->171000<--
# Total Sample Generated: 171000
# Total Sample Rejected: 162163
# Total Sample Accepted: 8837
# Evidence Seen: 8837
# Required Sample Seen: 145
# ************************************
# ************************************
# STATUS: Iteration Number -->172000<--
# Total Sample Generated: 172000
# Total Sample Rejected: 163109
# Total Sample Accepted: 8891
# Evidence Seen: 8891
# Required Sample Seen: 145
# ************************************
# ************************************
# STATUS: Iteration Number -->173000<--
# Total Sample Generated: 173000
# Total Sample Rejected: 164060
# Total Sample Accepted: 8940
# Evidence Seen: 8940
# Required Sample Seen: 145
# ************************************
# ************************************
# STATUS: Iteration Number -->174000<--
# Total Sample Generated: 174000
# Total Sample Rejected: 165011
# Total Sample Accepted: 8989
# Evidence Seen: 8989
# Required Sample Seen: 146
# ************************************
# ************************************
# STATUS: Iteration Number -->175000<--
# Total Sample Generated: 175000
# Total Sample Rejected: 165977
# Total Sample Accepted: 9023
# Evidence Seen: 9023
# Required Sample Seen: 148
# ************************************
# ************************************
# STATUS: Iteration Number -->176000<--
# Total Sample Generated: 176000
# Total Sample Rejected: 166916
# Total Sample Accepted: 9084
# Evidence Seen: 9084
# Required Sample Seen: 149
# ************************************
# ************************************
# STATUS: Iteration Number -->177000<--
# Total Sample Generated: 177000
# Total Sample Rejected: 167873
# Total Sample Accepted: 9127
# Evidence Seen: 9127
# Required Sample Seen: 150
# ************************************
# ************************************
# STATUS: Iteration Number -->178000<--
# Total Sample Generated: 178000
# Total Sample Rejected: 168829
# Total Sample Accepted: 9171
# Evidence Seen: 9171
# Required Sample Seen: 151
# ************************************
# ************************************
# STATUS: Iteration Number -->179000<--
# Total Sample Generated: 179000
# Total Sample Rejected: 169771
# Total Sample Accepted: 9229
# Evidence Seen: 9229
# Required Sample Seen: 152
# ************************************
# ************************************
# STATUS: Iteration Number -->180000<--
# Total Sample Generated: 180000
# Total Sample Rejected: 170719
# Total Sample Accepted: 9281
# Evidence Seen: 9281
# Required Sample Seen: 153
# ************************************
# ************************************
# STATUS: Iteration Number -->181000<--
# Total Sample Generated: 181000
# Total Sample Rejected: 171684
# Total Sample Accepted: 9316
# Evidence Seen: 9316
# Required Sample Seen: 155
# ************************************
# ************************************
# STATUS: Iteration Number -->182000<--
# Total Sample Generated: 182000
# Total Sample Rejected: 172637
# Total Sample Accepted: 9363
# Evidence Seen: 9363
# Required Sample Seen: 155
# ************************************
# ************************************
# STATUS: Iteration Number -->183000<--
# Total Sample Generated: 183000
# Total Sample Rejected: 173586
# Total Sample Accepted: 9414
# Evidence Seen: 9414
# Required Sample Seen: 155
# ************************************
# ************************************
# STATUS: Iteration Number -->184000<--
# Total Sample Generated: 184000
# Total Sample Rejected: 174525
# Total Sample Accepted: 9475
# Evidence Seen: 9475
# Required Sample Seen: 158
# ************************************
# ************************************
# STATUS: Iteration Number -->185000<--
# Total Sample Generated: 185000
# Total Sample Rejected: 175479
# Total Sample Accepted: 9521
# Evidence Seen: 9521
# Required Sample Seen: 159
# ************************************
# ************************************
# STATUS: Iteration Number -->186000<--
# Total Sample Generated: 186000
# Total Sample Rejected: 176432
# Total Sample Accepted: 9568
# Evidence Seen: 9568
# Required Sample Seen: 159
# ************************************
# ************************************
# STATUS: Iteration Number -->187000<--
# Total Sample Generated: 187000
# Total Sample Rejected: 177383
# Total Sample Accepted: 9617
# Evidence Seen: 9617
# Required Sample Seen: 161
# ************************************
# ************************************
# STATUS: Iteration Number -->188000<--
# Total Sample Generated: 188000
# Total Sample Rejected: 178340
# Total Sample Accepted: 9660
# Evidence Seen: 9660
# Required Sample Seen: 161
# ************************************
# ************************************
# STATUS: Iteration Number -->189000<--
# Total Sample Generated: 189000
# Total Sample Rejected: 179295
# Total Sample Accepted: 9705
# Evidence Seen: 9705
# Required Sample Seen: 162
# ************************************
# ************************************
# STATUS: Iteration Number -->190000<--
# Total Sample Generated: 190000
# Total Sample Rejected: 180227
# Total Sample Accepted: 9773
# Evidence Seen: 9773
# Required Sample Seen: 162
# ************************************
# ************************************
# STATUS: Iteration Number -->191000<--
# Total Sample Generated: 191000
# Total Sample Rejected: 181177
# Total Sample Accepted: 9823
# Evidence Seen: 9823
# Required Sample Seen: 162
# ************************************
# ************************************
# STATUS: Iteration Number -->192000<--
# Total Sample Generated: 192000
# Total Sample Rejected: 182130
# Total Sample Accepted: 9870
# Evidence Seen: 9870
# Required Sample Seen: 162
# ************************************
# ************************************
# STATUS: Iteration Number -->193000<--
# Total Sample Generated: 193000
# Total Sample Rejected: 183075
# Total Sample Accepted: 9925
# Evidence Seen: 9925
# Required Sample Seen: 162
# ************************************
# ************************************
# STATUS: Iteration Number -->194000<--
# Total Sample Generated: 194000
# Total Sample Rejected: 184021
# Total Sample Accepted: 9979
# Evidence Seen: 9979
# Required Sample Seen: 164
# ************************************
# -----------------------------------------------------------
# Completed 194308 Iterators of Sampling.
# Final Result:
# Total Sample Generated = 194308
# Total Sample Rejected = 194143
# Total Sample Accepted = 10000
# Total Required Sample Seen: {'B': '+b'} | {'J': '+j'} = 165
# Total Evidence Seen: {'J': '+j'} = 10000
# Probability = 0.0165
# -----------------------------------------------------------

# %% [markdown]
# ## Now Lets Calculate the Query result using Rejection Sampling Method:
# `With verbose = False`
# - Just to see the final result.

# %%
bayesNet.doRejectionSampling(TOTAL_SAMPLE_REQUIRED = 10000, verbose = False)
# Out:
# ------------ CALCULATE THE QUERY USING REJECTION SAMPLING ------------
# -----------------------------------------------------------
# Completed 190183 Iterators of Sampling.
# Final Result:
# Total Sample Generated = 190183
# Total Sample Rejected = 189992
# Total Sample Accepted = 10000
# Total Required Sample Seen: {'B': '+b'} | {'J': '+j'} = 191
# Total Evidence Seen: {'J': '+j'} = 10000
# Probability = 0.0191
# -----------------------------------------------------------

# %% [markdown]
# ## Let's See how a single weighted sample is generated:

# %%
bayesNet.generateWeightedSample(verbose = True)
# Out:
# Started Generating a Single Sample...
# ---------------------------------------------------------------------------------
# With Probability 0.6199478072745186: {'B': '-b'} is chosen till now...
# ---------------------------------------------------------------------------------
# With Probability 0.7684955187656174: {'B': '-b', 'E': '-e'} is chosen till now...
# ---------------------------------------------------------------------------------
# With Probability 0.2893158384689761: {'B': '-b', 'E': '-e', 'A': '-a'} is chosen till now...
# ---------------------------------------------------------------------------------
# Fixing The Sample: J = +j
# Sample Chosen Till Now: {'B': '-b', 'E': '-e', 'A': '-a', 'J': '+j'}
# Updated Sample Weights are: 0.05
# ---------------------------------------------------------------------------------
# With Probability 0.3194054300011471: {'B': '-b', 'E': '-e', 'A': '-a', 'J': '+j', 'M': '-m'} is chosen till now...
# *********************************************************************************
# Final Sample Generated: {'B': '-b', 'E': '-e', 'A': '-a', 'J': '+j', 'M': '-m'}
# Final Weight: 0.05
# *********************************************************************************
# ({'B': '-b', 'E': '-e', 'A': '-a', 'J': '+j', 'M': '-m'}, 0.05)

# %% [markdown]
# ## Now Lets Calculate the Query result using Likelihood Weighting Method:
# `With verbose = True`

# %%
bayesNet.doLikelihoodWeighting(TOTAL_SAMPLE = 10000, verbose = True)
# Out:
# ------------ CALCULATE THE QUERY USING LIKELIHOOD WEIGHTING ------------
# Started Generating The Sample...
# ************************************
# STATUS: Iteration Number -->100<--
# Total Evidence Weight: 4.99999999999999
# Total Required Sample Weight: 0.0
# ************************************
# ************************************
# STATUS: Iteration Number -->200<--
# Total Evidence Weight: 10.000000000000007
# Total Required Sample Weight: 0.0
# ************************************
# ************************************
# STATUS: Iteration Number -->300<--
# Total Evidence Weight: 15.000000000000078
# Total Required Sample Weight: 0.0
# ************************************
# ************************************
# STATUS: Iteration Number -->400<--
# Total Evidence Weight: 20.850000000000147
# Total Required Sample Weight: 0.0
# ************************************
# ************************************
# STATUS: Iteration Number -->500<--
# Total Evidence Weight: 26.700000000000216
# Total Required Sample Weight: 0.0
# ************************************
# ************************************
# STATUS: Iteration Number -->600<--
# Total Evidence Weight: 32.550000000000246
# Total Required Sample Weight: 0.0
# ************************************
# ************************************
# STATUS: Iteration Number -->700<--
# Total Evidence Weight: 37.54999999999996
# Total Required Sample Weight: 0.0
# ************************************
# ************************************
# STATUS: Iteration Number -->800<--
# Total Evidence Weight: 42.54999999999968
# Total Required Sample Weight: 0.0
# ************************************
# ************************************
# STATUS: Iteration Number -->900<--
# Total Evidence Weight: 47.54999999999939
# Total Required Sample Weight: 0.0
# ************************************
# ************************************
# STATUS: Iteration Number -->1000<--
# Total Evidence Weight: 53.39999999999911
# Total Required Sample Weight: 0.9
# ************************************
# ************************************
# STATUS: Iteration Number -->1100<--
# Total Evidence Weight: 58.399999999998826
# Total Required Sample Weight: 0.9
# ************************************
# ************************************
# STATUS: Iteration Number -->1200<--
# Total Evidence Weight: 63.39999999999854
# Total Required Sample Weight: 0.9
# ************************************
# ************************************
# STATUS: Iteration Number -->1300<--
# Total Evidence Weight: 68.39999999999826
# Total Required Sample Weight: 0.9
# ************************************
# ************************************
# STATUS: Iteration Number -->1400<--
# Total Evidence Weight: 74.24999999999798
# Total Required Sample Weight: 0.9
# ************************************
# ************************************
# STATUS: Iteration Number -->1500<--
# Total Evidence Weight: 80.0999999999977
# Total Required Sample Weight: 0.9
# ************************************
# ************************************
# STATUS: Iteration Number -->1600<--
# Total Evidence Weight: 85.09999999999742
# Total Required Sample Weight: 0.9
# ************************************
# ************************************
# STATUS: Iteration Number -->1700<--
# Total Evidence Weight: 90.09999999999714
# Total Required Sample Weight: 0.9
# ************************************
# ************************************
# STATUS: Iteration Number -->1800<--
# Total Evidence Weight: 95.94999999999686
# Total Required Sample Weight: 0.9
# ************************************
# ************************************
# STATUS: Iteration Number -->1900<--
# Total Evidence Weight: 100.94999999999658
# Total Required Sample Weight: 0.9
# ************************************
# ************************************
# STATUS: Iteration Number -->2000<--
# Total Evidence Weight: 105.9499999999963
# Total Required Sample Weight: 0.9
# ************************************
# ************************************
# STATUS: Iteration Number -->2100<--
# Total Evidence Weight: 110.94999999999601
# Total Required Sample Weight: 0.9
# ************************************
# ************************************
# STATUS: Iteration Number -->2200<--
# Total Evidence Weight: 116.79999999999573
# Total Required Sample Weight: 0.9
# ************************************
# ************************************
# STATUS: Iteration Number -->2300<--
# Total Evidence Weight: 121.79999999999545
# Total Required Sample Weight: 0.9
# ************************************
# ************************************
# STATUS: Iteration Number -->2400<--
# Total Evidence Weight: 127.64999999999517
# Total Required Sample Weight: 0.9
# ************************************
# ************************************
# STATUS: Iteration Number -->2500<--
# Total Evidence Weight: 132.6499999999962
# Total Required Sample Weight: 0.9
# ************************************
# ************************************
# STATUS: Iteration Number -->2600<--
# Total Evidence Weight: 137.64999999999733
# Total Required Sample Weight: 0.9
# ************************************
# ************************************
# STATUS: Iteration Number -->2700<--
# Total Evidence Weight: 144.34999999999846
# Total Required Sample Weight: 1.8
# ************************************
# ************************************
# STATUS: Iteration Number -->2800<--
# Total Evidence Weight: 149.3499999999996
# Total Required Sample Weight: 1.8
# ************************************
# ************************************
# STATUS: Iteration Number -->2900<--
# Total Evidence Weight: 154.35000000000073
# Total Required Sample Weight: 1.8
# ************************************
# ************************************
# STATUS: Iteration Number -->3000<--
# Total Evidence Weight: 160.20000000000186
# Total Required Sample Weight: 2.7
# ************************************
# ************************************
# STATUS: Iteration Number -->3100<--
# Total Evidence Weight: 165.200000000003
# Total Required Sample Weight: 2.7
# ************************************
# ************************************
# STATUS: Iteration Number -->3200<--
# Total Evidence Weight: 171.05000000000413
# Total Required Sample Weight: 2.7
# ************************************
# ************************************
# STATUS: Iteration Number -->3300<--
# Total Evidence Weight: 176.05000000000527
# Total Required Sample Weight: 2.7
# ************************************
# ************************************
# STATUS: Iteration Number -->3400<--
# Total Evidence Weight: 181.0500000000064
# Total Required Sample Weight: 2.7
# ************************************
# ************************************
# STATUS: Iteration Number -->3500<--
# Total Evidence Weight: 186.05000000000754
# Total Required Sample Weight: 2.7
# ************************************
# ************************************
# STATUS: Iteration Number -->3600<--
# Total Evidence Weight: 191.05000000000868
# Total Required Sample Weight: 2.7
# ************************************
# ************************************
# STATUS: Iteration Number -->3700<--
# Total Evidence Weight: 196.05000000000982
# Total Required Sample Weight: 2.7
# ************************************
# ************************************
# STATUS: Iteration Number -->3800<--
# Total Evidence Weight: 201.90000000001095
# Total Required Sample Weight: 3.6
# ************************************
# ************************************
# STATUS: Iteration Number -->3900<--
# Total Evidence Weight: 206.90000000001208
# Total Required Sample Weight: 3.6
# ************************************
# ************************************
# STATUS: Iteration Number -->4000<--
# Total Evidence Weight: 212.75000000001322
# Total Required Sample Weight: 3.6
# ************************************
# ************************************
# STATUS: Iteration Number -->4100<--
# Total Evidence Weight: 217.75000000001435
# Total Required Sample Weight: 3.6
# ************************************
# ************************************
# STATUS: Iteration Number -->4200<--
# Total Evidence Weight: 223.60000000001548
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->4300<--
# Total Evidence Weight: 228.60000000001662
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->4400<--
# Total Evidence Weight: 233.60000000001776
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->4500<--
# Total Evidence Weight: 238.6000000000189
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->4600<--
# Total Evidence Weight: 243.60000000002003
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->4700<--
# Total Evidence Weight: 248.60000000002117
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->4800<--
# Total Evidence Weight: 254.4500000000223
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->4900<--
# Total Evidence Weight: 259.4500000000234
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->5000<--
# Total Evidence Weight: 264.45000000002454
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->5100<--
# Total Evidence Weight: 269.4500000000257
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->5200<--
# Total Evidence Weight: 274.4500000000268
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->5300<--
# Total Evidence Weight: 279.45000000002796
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->5400<--
# Total Evidence Weight: 284.4500000000291
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->5500<--
# Total Evidence Weight: 289.45000000003023
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->5600<--
# Total Evidence Weight: 294.45000000003137
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->5700<--
# Total Evidence Weight: 299.4500000000325
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->5800<--
# Total Evidence Weight: 304.45000000003364
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->5900<--
# Total Evidence Weight: 309.4500000000348
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->6000<--
# Total Evidence Weight: 314.4500000000359
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->6100<--
# Total Evidence Weight: 319.45000000003705
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->6200<--
# Total Evidence Weight: 325.30000000003815
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->6300<--
# Total Evidence Weight: 330.3000000000393
# Total Required Sample Weight: 4.5
# ************************************
# ************************************
# STATUS: Iteration Number -->6400<--
# Total Evidence Weight: 336.1500000000404
# Total Required Sample Weight: 5.4
# ************************************
# ************************************
# STATUS: Iteration Number -->6500<--
# Total Evidence Weight: 341.15000000004153
# Total Required Sample Weight: 5.4
# ************************************
# ************************************
# STATUS: Iteration Number -->6600<--
# Total Evidence Weight: 346.15000000004267
# Total Required Sample Weight: 5.4
# ************************************
# ************************************
# STATUS: Iteration Number -->6700<--
# Total Evidence Weight: 351.1500000000438
# Total Required Sample Weight: 5.4
# ************************************
# ************************************
# STATUS: Iteration Number -->6800<--
# Total Evidence Weight: 356.15000000004494
# Total Required Sample Weight: 5.4
# ************************************
# ************************************
# STATUS: Iteration Number -->6900<--
# Total Evidence Weight: 361.1500000000461
# Total Required Sample Weight: 5.4
# ************************************
# ************************************
# STATUS: Iteration Number -->7000<--
# Total Evidence Weight: 366.1500000000472
# Total Required Sample Weight: 5.4
# ************************************
# ************************************
# STATUS: Iteration Number -->7100<--
# Total Evidence Weight: 371.15000000004835
# Total Required Sample Weight: 5.4
# ************************************
# ************************************
# STATUS: Iteration Number -->7200<--
# Total Evidence Weight: 376.1500000000495
# Total Required Sample Weight: 5.45
# ************************************
# ************************************
# STATUS: Iteration Number -->7300<--
# Total Evidence Weight: 381.1500000000506
# Total Required Sample Weight: 5.45
# ************************************
# ************************************
# STATUS: Iteration Number -->7400<--
# Total Evidence Weight: 386.15000000005176
# Total Required Sample Weight: 5.45
# ************************************
# ************************************
# STATUS: Iteration Number -->7500<--
# Total Evidence Weight: 391.1500000000529
# Total Required Sample Weight: 5.45
# ************************************
# ************************************
# STATUS: Iteration Number -->7600<--
# Total Evidence Weight: 396.15000000005404
# Total Required Sample Weight: 5.45
# ************************************
# ************************************
# STATUS: Iteration Number -->7700<--
# Total Evidence Weight: 401.1500000000552
# Total Required Sample Weight: 5.45
# ************************************
# ************************************
# STATUS: Iteration Number -->7800<--
# Total Evidence Weight: 406.1500000000563
# Total Required Sample Weight: 5.45
# ************************************
# ************************************
# STATUS: Iteration Number -->7900<--
# Total Evidence Weight: 411.15000000005745
# Total Required Sample Weight: 5.45
# ************************************
# ************************************
# STATUS: Iteration Number -->8000<--
# Total Evidence Weight: 416.1500000000586
# Total Required Sample Weight: 5.45
# ************************************
# ************************************
# STATUS: Iteration Number -->8100<--
# Total Evidence Weight: 421.1500000000597
# Total Required Sample Weight: 5.45
# ************************************
# ************************************
# STATUS: Iteration Number -->8200<--
# Total Evidence Weight: 426.15000000006086
# Total Required Sample Weight: 5.45
# ************************************
# ************************************
# STATUS: Iteration Number -->8300<--
# Total Evidence Weight: 432.00000000006196
# Total Required Sample Weight: 5.45
# ************************************
# ************************************
# STATUS: Iteration Number -->8400<--
# Total Evidence Weight: 437.0000000000631
# Total Required Sample Weight: 5.45
# ************************************
# ************************************
# STATUS: Iteration Number -->8500<--
# Total Evidence Weight: 442.8500000000642
# Total Required Sample Weight: 5.45
# ************************************
# ************************************
# STATUS: Iteration Number -->8600<--
# Total Evidence Weight: 448.7000000000653
# Total Required Sample Weight: 5.45
# ************************************
# ************************************
# STATUS: Iteration Number -->8700<--
# Total Evidence Weight: 453.70000000006644
# Total Required Sample Weight: 5.45
# ************************************
# ************************************
# STATUS: Iteration Number -->8800<--
# Total Evidence Weight: 459.55000000006754
# Total Required Sample Weight: 6.3500000000000005
# ************************************
# ************************************
# STATUS: Iteration Number -->8900<--
# Total Evidence Weight: 464.5500000000687
# Total Required Sample Weight: 6.3500000000000005
# ************************************
# ************************************
# STATUS: Iteration Number -->9000<--
# Total Evidence Weight: 469.5500000000698
# Total Required Sample Weight: 6.3500000000000005
# ************************************
# ************************************
# STATUS: Iteration Number -->9100<--
# Total Evidence Weight: 474.55000000007095
# Total Required Sample Weight: 6.3500000000000005
# ************************************
# ************************************
# STATUS: Iteration Number -->9200<--
# Total Evidence Weight: 479.5500000000721
# Total Required Sample Weight: 6.3500000000000005
# ************************************
# ************************************
# STATUS: Iteration Number -->9300<--
# Total Evidence Weight: 485.4000000000732
# Total Required Sample Weight: 6.3500000000000005
# ************************************
# ************************************
# STATUS: Iteration Number -->9400<--
# Total Evidence Weight: 491.2500000000743
# Total Required Sample Weight: 6.3500000000000005
# ************************************
# ************************************
# STATUS: Iteration Number -->9500<--
# Total Evidence Weight: 496.25000000007543
# Total Required Sample Weight: 6.3500000000000005
# ************************************
# ************************************
# STATUS: Iteration Number -->9600<--
# Total Evidence Weight: 501.25000000007657
# Total Required Sample Weight: 6.3500000000000005
# ************************************
# ************************************
# STATUS: Iteration Number -->9700<--
# Total Evidence Weight: 506.2500000000777
# Total Required Sample Weight: 6.3500000000000005
# ************************************
# ************************************
# STATUS: Iteration Number -->9800<--
# Total Evidence Weight: 511.25000000007884
# Total Required Sample Weight: 6.3500000000000005
# ************************************
# ************************************
# STATUS: Iteration Number -->9900<--
# Total Evidence Weight: 516.2500000000751
# Total Required Sample Weight: 6.3500000000000005
# ************************************
# ************************************
# STATUS: Iteration Number -->10000<--
# Total Evidence Weight: 522.1000000000706
# Total Required Sample Weight: 7.250000000000001
# ************************************
# ------------------------------------------------------------------
# Completed 10000 Iterators of Sampling.
# Final Result:
# Total Sample Generated = 10000
# Total Required Sample Weight Seen: {'B': '+b'} | {'J': '+j'} = 7.250000000000001
# Total Evidence Weight Seen: {'J': '+j'} = 522.1000000000706
# Probability = 0.013886228691819614
# ------------------------------------------------------------------

# %% [markdown]
# ## Now Lets Calculate the Query result using Likelihood Weighting Method:
# `With verbose = False`
# - Just to see the final result.

# %%
bayesNet.doLikelihoodWeighting(TOTAL_SAMPLE = 10000, verbose = False)
# Out:
# ------------ CALCULATE THE QUERY USING LIKELIHOOD WEIGHTING ------------
# ------------------------------------------------------------------
# Completed 10000 Iterators of Sampling.
# Final Result:
# Total Sample Generated = 10000
# Total Required Sample Weight Seen: {'B': '+b'} | {'J': '+j'} = 11.750000000000002
# Total Evidence Weight Seen: {'J': '+j'} = 519.5500000000724
# Probability = 0.022615725146758473
# ------------------------------------------------------------------

# %% [markdown]
# <center>
# Thank You
# </center>
